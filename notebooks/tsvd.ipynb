# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
import drnb as nb
# Out:
# time: 4.47 s (started: 2022-09-04 15:53:56 -07:00)

# %% [markdown]
# Using truncated SVD *should* give the same results as using `method="pca"`. With default settings, large datasets will use the truncated SVD method under the hood.

# %%
s1k_tsvd = nb.embed_data("s1k", method="tsvd", eval_metrics=["rte", "rpc", "gs"])
# Out:
# time: 768 ms (started: 2022-09-04 15:54:00 -07:00)

# %%
s1k_tsvd["evaluations"]
# Out:
# [('rte', 0.6724), ('rpc', 0.5170724130619744), ('gs', 1.0)]
# time: 3.38 ms (started: 2022-09-04 15:54:01 -07:00)

# %% [markdown]
# By definition, the "Global Score" assessment (here given as `'gs'`) for PCA is 1. See the [TriMap paper](https://arxiv.org/abs/1910.00204) for more on its definition.

# %%
nb.embed_data("iris", method="tsvd", eval_metrics=["rte", "rpc", "gs"])["evaluations"]
# Out:
# [('rte', 0.976), ('rpc', 0.9985220311746157), ('gs', 0.9999999)]
# time: 356 ms (started: 2022-09-04 15:54:01 -07:00)
