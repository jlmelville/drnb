# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
# Out:
# time: 250 ms (started: 2022-11-18 15:48:18 -08:00)

# %% [markdown]
# **Note**: the ncvis method is optional because it hasn't been updated in a while and is difficult (impossible?) to install on ARM-based Macs. To make this notebook work, you need to `pip install ncvis` first.

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("ncvis"),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force", palette="Accent"),
)
# Out:
# time: 6.5 s (started: 2022-11-18 15:48:18 -08:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [15:48:25] INFO     Using experiment name: experiment-20221118234825                                 ]8;id=938347;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=310452;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#41\41]8;;\
#            INFO     Getting dataset s1k                                                              ]8;id=704150;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=129396;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#51\51]8;;\
#            INFO     Embedding                                                                        ]8;id=441681;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=355974;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#54\54]8;;\
# ...

# %% [markdown]
# NCVis parameters taken from [the Python wrapper](https://github.com/stat-ml/ncvis/blob/master/wrapper/ncvis.pyx) docs.
#
# * `n_threads=-1`: < 1 means use all available CPUs (as calculated by `multiprocessing.cpu_count()`).
# * `n_neighbors=15`
# * `M=16`: HNSW parameter.
# * `ef_construction=200`: another HNSW parameter.
# * `random_seed=42`
# * `n_epochs=50`
# * `n_init_epochs=20`: number of iterations spent during initialization. The NCVis describes this as a power iteration method.
# * `spread=1.0`: same as the UMAP parameter.
# * `min_dist=0.4`: same as the UMAP parameter (but larger default compared to UMAP's `0.1`).
# * `a=None`: same as the UMAP parameter.
# * `b=None`: same as the UMAP parameter.
# * `alpha=1.0`: learning rate for coordinate updates.
# * `alpha_Q=1.0`: learning rate for the normalization factor `Q`.
# * `n_noise=None`: The number of noise samples to use per item. UMAP default is `5`. This can also be an array with the number of noise samples to use per per epoch if you want this to vary. `n_epochs` is ignored if this is set, instead the length of the array is used to specify the number of epochs. By default the number of negative samples grows cubically with the epoch number, scaled so that approximately the same total number of noise samples are used as would result if using a fixed value of `n_noise=5`. The result is only approximate because the number of noise samples per item must be at least 1 so rounding up at early iterations means that more than `5 x n_epochs` noise samples can result.
# * `distance="euclidean"` one of: (`"euclidean"`, `"cosine"`, `"correlation"`, `"inner_product"`)

# %%
embed_result_a1b1n5 = pl.create_pipeline(
    method=pl.embedder("ncvis", dict(a=1, b=1, n_noise=5)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
).run("s1k")
# Out:
# [15:48:36] INFO     Using experiment name: experiment-20221118234836                                 ]8;id=589983;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=520447;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#41\41]8;;\
#            INFO     Getting dataset s1k                                                              ]8;id=888229;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=719894;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#51\51]8;;\
#            INFO     Embedding                                                                        ]8;id=658546;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=916301;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#54\54]8;;\
# ...

# %% [markdown]
# Cauchy-UMAP like settings:

# %%
embed_result_mnist = pl.create_pipeline(
    method=pl.embedder("ncvis", dict(a=1, b=1, n_noise=5)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
).run("mnist")
# Out:
# [15:48:47] INFO     Using experiment name: experiment-20221118234847                                 ]8;id=935604;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=853273;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#41\41]8;;\
#            INFO     Getting dataset mnist                                                            ]8;id=407313;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=944018;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#51\51]8;;\
# [15:48:48] INFO     Embedding                                                                        ]8;id=283350;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=878565;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#54\54]8;;\
# ...

# %% [markdown]
# NCVIS defaults

# %%
embed_result_mnist = pl.create_pipeline(
    method=pl.embedder("ncvis"),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
).run("mnist")
# Out:
# [17:13:41] INFO     Using experiment name: experiment-20221106001341                                 ]8;id=225954;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=365487;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#41\41]8;;\
#            INFO     Getting dataset mnist                                                            ]8;id=711045;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=952275;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#51\51]8;;\
#            INFO     Embedding                                                                        ]8;id=253135;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=995178;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#54\54]8;;\
# ...
