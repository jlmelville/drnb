# %% [markdown]
# PyMDE is PyTorch-powered. So you may have to work a bit to get this to install: ensure the version
# of PyTorch you install supports the version of CUDA that your GPU uses. If you don't have a GPU
# I am not sure how easy feasible it is to run PyMDE (I do not currently support MPS for this and
# don't know how well it works).
#
# See the [Minimum Distortion Embeddings](https://web.stanford.edu/~boyd/papers/min_dist_emb.html)
# monograph and the PyMDE website <https://pymde.org/> website for more.

# %%
import numpy as np
import pandas as pd

# %%
import drnb.embed.pipeline as pl

pl.standard_eval(
    method="pymde-plugin",
    dataset="s1k",
    verbose=True,
)
# Out:
# [14:24:33] INFO     Getting dataset s1k                                              ]8;id=462798;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=480374;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#246\246]8;;\
#            INFO     Embedding                                                        ]8;id=349714;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=509508;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#249\249]8;;\
#            INFO     [external:pymde-plugin] launching: /home/james/.local/bin/uv run ]8;id=777545;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=638726;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#156\156]8;;\
#                     --color never --quiet drnb-plugin-run.py --method pymde-plugin
#                     --request /tmp/drnb-pymde-plugin-ciigevp0/request.json
# [14:24:39] INFO     Running PyMDE with params={}                                     ]8;id=509890;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=895964;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#299\299]8;;\
# [14:24:40] INFO     Running preserve neighbors with knn                              ]8;id=187605;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=785771;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#299\299]8;;\
# [14:24:43] INFO     Embedding completed                                              ]8;id=54484;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=426716;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#299\299]8;;\
# [14:24:44] INFO     [external:pymde-plugin] kept plugin workspace at                 ]8;id=256096;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=306315;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#234\234]8;;\
#                     /tmp/drnb-pymde-plugin-ciigevp0
#            INFO     Evaluating                                                       ]8;id=848605;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=994225;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#271\271]8;;\
#            INFO     rte-5-euclidean                                                       ]8;id=264774;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=915015;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#61\61]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=727388;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=609636;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                  ]8;id=931088;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=488814;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#295\295]8;;\
#            INFO     Also found corresponding euclidean distances                     ]8;id=937385;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=516087;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#298\298]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=774656;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=335613;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     rpc-5-euclidean                                                       ]8;id=455157;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=676941;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#61\61]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=169652;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=982450;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                  ]8;id=46823;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=44812;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#295\295]8;;\
#            INFO     Also found corresponding euclidean distances                     ]8;id=865830;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=909018;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#298\298]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=93568;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=271339;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     nnp-[15, 50, 150]-noself-euclidean                                    ]8;id=508222;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=303165;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#61\61]8;;\
#            INFO     Plotting                                                         ]8;id=486862;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=231295;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#281\281]8;;\
# [EvalResult(eval_type='RTE', label='rte-5-euclidean', value=np.float64(0.648), info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='RPC', label='rpc-5-euclidean', value=np.float32(0.47247565), info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='NNP', label='nnp-15-noself-euclidean', value=np.float64(0.2121333333333333), info={'metric': 'euclidean', 'n_neighbors': 15}),
#  EvalResult(eval_type='NNP', label='nnp-50-noself-euclidean', value=np.float64(0.40794), info={'metric': 'euclidean', 'n_neighbors': 50}),
#  EvalResult(eval_type='NNP', label='nnp-150-noself-euclidean', value=np.float64(0.5093599999999999), info={'metric': 'euclidean', 'n_neighbors': 150})]

# %% [markdown]
# PyMDE parameters from the docstring for [preserve_neighbors](https://github.com/cvxgrp/pymde/blob/0e9ab9ddccffb0bdc559cec7f7c614a5c1f0b93d/pymde/recipes.py#L221)
#
# * `attractive_penalty="log1p"`: the attractive part of the cost function. Other penalties from the same module are `"huber"` or `"quadratic"`.
# You should provide a function with the same name as one of the functions in the [pymde.functions.penalties](https://github.com/cvxgrp/pymde/blob/main/pymde/functions/penalties.py)
# module.
# * `repulsive_penalty="log"`: the repulsive part of the cost function. The pymde documentation says that you should only consider one of
# `"log"`, `"invpower"`, or `"logratio"`. If `None` then only positive interactions are considered.
# * `constraint=None`: a constraint that can be used instead of `repulsive_penalty`. Should be one of
# `"standardized"` or `"centered"`. If `repulsive_penalty` is not supplied then `"standardized"` is
# used. You can learn more about constraints by looking at the [pymde.constraints](https://github.com/cvxgrp/pymde/blob/main/pymde/constraints.py)
# module, but in `drnb` only the two options mentioned are supported.
# * `n_neighbors=None`: by default, a value between `5-15` is used, depending on an attempt to use ~1% of the total edges in the dataset as positive edges. Practically, this means datasets < 1200 items have `n_neighbors=5`, and datasets > 3000 have `n_neighbors=15`.
# * `repulsive_fraction=None`: fraction of edges (relative to the number of attractive edges) to include in the `repulsive_penalty` calculation. Usually `1`, i.e. the same number of repulsive edges as attractive edges.
# * `max_distance=None` If set, the maximum distance a nearest neighbor can have.
# * `init="quadratic"` The initialization method. The default, `"quadratic"`, is a Laplacian eigenmap initialization. Otherwise, `"random"` is a random initialization using normal distribution (mean 0, standard deviation 1).

# %%
pl.standard_eval(
    method="pymde-plugin",
    dataset="s1k",
    params=dict(
        attractive_penalty="quadratic",
        repulsive_penalty=None,
        constraint="standardized",
    ),
    verbose=True,
)
# Out:
# [14:24:45] INFO     Getting dataset s1k                                              ]8;id=848862;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=924956;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#246\246]8;;\
#            INFO     Embedding                                                        ]8;id=761048;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=640524;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#249\249]8;;\
#            INFO     [external:pymde-plugin] launching: /home/james/.local/bin/uv run ]8;id=627788;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=270630;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#156\156]8;;\
#                     --color never --quiet drnb-plugin-run.py --method pymde-plugin
#                     --request /tmp/drnb-pymde-plugin-9hoc9lv1/request.json
# [14:24:49] INFO     attractive penalty: quadratic                                    ]8;id=109303;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=990456;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#299\299]8;;\
#            INFO     constraint: standardized                                         ]8;id=690122;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=28699;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#299\299]8;;\
#            INFO     Running PyMDE with params={'attractive_penalty': '<type>',       ]8;id=166821;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=923949;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#299\299]8;;\
#                     'repulsive_penalty': None, 'constraint': '<_Standardized>'}
#            INFO     Running preserve neighbors with knn                              ]8;id=905764;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=678914;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#299\299]8;;\
# [14:24:59] INFO     Embedding completed                                              ]8;id=94266;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=656412;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#299\299]8;;\
#            INFO     [external:pymde-plugin] kept plugin workspace at                 ]8;id=666256;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py\external.py]8;;\:]8;id=748726;file:///home/james/dev/drnb-plugin/src/drnb/plugins/external.py#234\234]8;;\
#                     /tmp/drnb-pymde-plugin-9hoc9lv1
#            INFO     Evaluating                                                       ]8;id=625014;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=66386;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#271\271]8;;\
#            INFO     rte-5-euclidean                                                       ]8;id=945749;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=566623;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#61\61]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=274205;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=37288;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                  ]8;id=978140;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=452509;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#295\295]8;;\
#            INFO     Also found corresponding euclidean distances                     ]8;id=36225;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=302818;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#298\298]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=969569;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=68866;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     rpc-5-euclidean                                                       ]8;id=949249;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=721500;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#61\61]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=918086;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=534345;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
# [14:25:00] INFO     Using triplets from triplets/s1k.5.1337.idx.npy                  ]8;id=747586;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=179234;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#295\295]8;;\
#            INFO     Also found corresponding euclidean distances                     ]8;id=345763;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=194180;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#298\298]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=268426;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=675537;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     nnp-[15, 50, 150]-noself-euclidean                                    ]8;id=997618;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=726072;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#61\61]8;;\
#            INFO     Plotting                                                         ]8;id=498769;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=522283;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#281\281]8;;\
# [EvalResult(eval_type='RTE', label='rte-5-euclidean', value=np.float64(0.6788), info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='RPC', label='rpc-5-euclidean', value=np.float32(0.526541), info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='NNP', label='nnp-15-noself-euclidean', value=np.float64(0.1192), info={'metric': 'euclidean', 'n_neighbors': 15}),
#  EvalResult(eval_type='NNP', label='nnp-50-noself-euclidean', value=np.float64(0.24710000000000001), info={'metric': 'euclidean', 'n_neighbors': 50}),
#  EvalResult(eval_type='NNP', label='nnp-150-noself-euclidean', value=np.float64(0.3953666666666667), info={'metric': 'euclidean', 'n_neighbors': 150})]
