# %%
# %load_ext lab_black
# %load_ext autotime
import numpy as np
import pandas as pd
# Out:
# time: 1.45 ms (started: 2022-09-17 12:57:26 -07:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("pymde"),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
)
# Out:
# time: 3.75 ms (started: 2022-09-17 12:57:27 -07:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [12:57:28] INFO     Getting dataset s1k                                                              ]8;id=399250;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=519868;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#37\37]8;;\
#            INFO     Embedding                                                                        ]8;id=380173;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=245925;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#40\40]8;;\
#            INFO     Running PyMDE                                                                       ]8;id=441732;file:///home/james/dev/drnb/src/drnb/embed/pymde.py\pymde.py]8;;\:]8;id=819323;file:///home/james/dev/drnb/src/drnb/embed/pymde.py#29\29]8;;\
# [12:57:37] INFO     Embedding completed                                                                 ]8;id=196825;file:///home/james/dev/drnb/src/drnb/embed/pymde.py\pymde.py]8;;\:]8;id=499734;file:///home/james/dev/drnb/src/drnb/embed/pymde.py#32\32]8;;\
#            INFO     Evaluating                                                                       ]8;id=954552;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=163189;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#43\43]8;;\
#            INFO     Random Triplet Evaluation num triplets per point: 5                              ]8;id=293700;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=798450;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=497264;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=484934;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=243356;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=971032;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=199027;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=249868;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Random Pair Correlation num triplets per point: 5                                ]8;id=315240;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=918293;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=642002;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=373627;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=711588;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=330888;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=177913;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=184087;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Neighbor Preservation for n_neighbors: [15, 50, 150] (excluding self)            ]8;id=407877;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=707306;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=791325;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=100813;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#54\54]8;;\
#            INFO     Could not load library with AVX2 support due to:                                   ]8;id=876847;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=161287;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#58\58]8;;\
#                     ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
#            INFO     Loading faiss.                                                                     ]8;id=692841;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=787681;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#64\64]8;;\
#            INFO     Successfully loaded faiss.                                                         ]8;id=744420;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=540471;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#66\66]8;;\
#            INFO     Plotting                                                                         ]8;id=803282;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=574441;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#46\46]8;;\
#            INFO     Looking for pkl format from data/s1k-target-palette.pkl                         ]8;id=152658;file:///home/james/dev/drnb/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=909922;file:///home/james/dev/drnb/src/drnb/io/__init__.py#151\151]8;;\
#            INFO     Exporting                                                                        ]8;id=886006;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=985219;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#49\49]8;;\
# time: 9.68 s (started: 2022-09-17 12:57:28 -07:00)

# %% [markdown]
# PyMDE parameters from the docstring for [preserve_neighbors](https://github.com/cvxgrp/pymde/blob/0e9ab9ddccffb0bdc559cec7f7c614a5c1f0b93d/pymde/recipes.py#L221)
#
# * `attractive_penalty=pymde.functions.penalties.Log1p`: the attractive part of the cost function. Other penalties from the same module are `Huber` or `Quadratic`.
# * `repulsive_penalty=pymde.functions.penalties.Log`: the repulsive part of the cost function. Another suitable penalty from the same module is `Quadratic`. If `None` then only positive interactions are considered.
# * `constraint=None`: a constraint (e.g. from `pymde.constraints`). If a `repulsive_penalty` is provided then this is not used, otherwise `pymde.Standardized()` is used.
# * `n_neighbors=None`: by default, a value between `5-15` is used, depending on an attempt to use ~1% of the total edges in the dataset as positive edges. Practically, this means datasets < 1200 items have `n_neighbors=5`, and datasets > 3000 have `n_neighbors=15`.
# * `repulsive_fraction=None`: fraction of edges (relative to the number of attractive edges) to include in the `repulsive_penalty` calculation. Usually `1`, i.e. the same number of repulsive edges as attractive edges.
# * `max_distance=None` If set, the maximum distance a nearest neighbor can have.
# * `init="quadratic"` The initialization method. The default, `"quadratic"`, is a Laplacian eigenmap initialization. Otherwise, `"random"` is a random initialization using normal distribution (mean 0, standard deviation 1).

# %%
import pymde

laplacian_result = pl.create_pipeline(
    method=pl.embedder(
        "pymde",
        seed=42,
        params=dict(
            attractive_penalty=pymde.penalties.Quadratic, repulsive_penalty=None
        ),
    ),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
).run("s1k")
# Out:
# [12:58:39] INFO     Getting dataset s1k                                                              ]8;id=551333;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=457081;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#37\37]8;;\
#            INFO     Embedding                                                                        ]8;id=527270;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=297961;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#40\40]8;;\
#            INFO     Running PyMDE                                                                       ]8;id=915211;file:///home/james/dev/drnb/src/drnb/embed/pymde.py\pymde.py]8;;\:]8;id=563460;file:///home/james/dev/drnb/src/drnb/embed/pymde.py#29\29]8;;\
# [12:58:48] INFO     Embedding completed                                                                 ]8;id=209757;file:///home/james/dev/drnb/src/drnb/embed/pymde.py\pymde.py]8;;\:]8;id=124899;file:///home/james/dev/drnb/src/drnb/embed/pymde.py#32\32]8;;\
#            INFO     Evaluating                                                                       ]8;id=545055;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=101344;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#43\43]8;;\
#            INFO     Random Triplet Evaluation num triplets per point: 5                              ]8;id=780228;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=301409;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=64507;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=880368;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=267331;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=990323;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=863167;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=779092;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Random Pair Correlation num triplets per point: 5                                ]8;id=680853;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=858080;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=892011;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=997032;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=172014;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=846662;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=49068;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=412813;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Neighbor Preservation for n_neighbors: [15, 50, 150] (excluding self)            ]8;id=893356;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=842653;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
# [12:58:49] INFO     Plotting                                                                         ]8;id=194087;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=49545;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#46\46]8;;\
#            INFO     Looking for pkl format from data/s1k-target-palette.pkl                         ]8;id=134975;file:///home/james/dev/drnb/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=913407;file:///home/james/dev/drnb/src/drnb/io/__init__.py#151\151]8;;\
#            INFO     Exporting                                                                        ]8;id=884953;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=380033;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#49\49]8;;\
# time: 10.1 s (started: 2022-09-17 12:58:39 -07:00)
