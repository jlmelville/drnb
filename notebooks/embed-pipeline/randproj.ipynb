# %%
import numpy as np
import pandas as pd

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("randproj", dict(random_state=42)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(
        cex=10,
        alpha_scale=1,
        figsize=(6, 4),
        legend="force",
    ),
)

# %%
embed_result = embed_pipeline.run("iris")
# Out:
# [09:18:27] INFO     Getting dataset iris                                             ]8;id=605067;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=17421;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#245\245]8;;\
#            INFO     Embedding                                                        ]8;id=246529;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=513907;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#248\248]8;;\
#            INFO     Running Sparse Random Projection                                 ]8;id=886027;file:///home/james/dev/drnb-plugin/src/drnb/embed/__init__.py\__init__.py]8;;\:]8;id=842561;file:///home/james/dev/drnb-plugin/src/drnb/embed/__init__.py#175\175]8;;\
#            INFO     Embedding completed                                              ]8;id=86227;file:///home/james/dev/drnb-plugin/src/drnb/embed/__init__.py\__init__.py]8;;\:]8;id=73903;file:///home/james/dev/drnb-plugin/src/drnb/embed/__init__.py#184\184]8;;\
#            INFO     Evaluating                                                       ]8;id=886110;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=65818;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#270\270]8;;\
#            INFO     rte-5-euclidean                                                       ]8;id=417483;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=430604;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#59\59]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=851451;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=149234;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     Using triplets from triplets/iris.5.1337.idx.npy                 ]8;id=201364;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=766380;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#295\295]8;;\
#            INFO     Also found corresponding euclidean distances                     ]8;id=860456;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=4022;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#298\298]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=344107;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=172143;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
# [09:18:28] INFO     rpc-5-euclidean                                                       ]8;id=52084;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=86143;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#59\59]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=37042;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=572780;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     Using triplets from triplets/iris.5.1337.idx.npy                 ]8;id=755904;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=714010;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#295\295]8;;\
#            INFO     Also found corresponding euclidean distances                     ]8;id=216192;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=30441;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#298\298]8;;\
#            INFO     Looking for precomputed triplets                                 ]8;id=111951;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py\triplets.py]8;;\:]8;id=281921;file:///home/james/dev/drnb-plugin/src/drnb/triplets.py#283\283]8;;\
#            INFO     nnp-[15, 50, 150]-noself-euclidean                                    ]8;id=916341;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py\base.py]8;;\:]8;id=611452;file:///home/james/dev/drnb-plugin/src/drnb/eval/base.py#59\59]8;;\
#            WARNING  151 nearest neighbors requested but only 150 items are available   ]8;id=142428;file:///home/james/dev/drnb-plugin/src/drnb/eval/nbrpres.py\nbrpres.py]8;;\:]8;id=43998;file:///home/james/dev/drnb-plugin/src/drnb/eval/nbrpres.py#75\75]8;;\
#            INFO     [nn-plugin:faiss] launching: /home/james/.local/bin/uv run       ]8;id=648104;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py\external.py]8;;\:]8;id=536934;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py#188\188]8;;\
#                     --color never --quiet drnb-nn-plugin-run.py --method faiss
#                     --request /tmp/drnb-nn-faiss-0cgf7crj/request.json
#            INFO     [faiss] request metric=euclidean n_neighbors=150                 ]8;id=649124;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py\external.py]8;;\:]8;id=108142;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py#287\287]8;;\
#            INFO     [faiss] params={'use_gpu': True}                                 ]8;id=144735;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py\external.py]8;;\:]8;id=405285;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py#287\287]8;;\
# [09:18:29] INFO     Plotting                                                         ]8;id=93355;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=773432;file:///home/james/dev/drnb-plugin/src/drnb/embed/pipeline.py#280\280]8;;\

# %%
embed_result["evaluations"]
# Out:
# [EvalResult(eval_type='RTE', label='rte-5-euclidean', value=np.float64(0.8986666666666665), info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='RPC', label='rpc-5-euclidean', value=np.float32(0.94808996), info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='NNP', label='nnp-15-noself-euclidean', value=np.float64(0.5955555555555555), info={'metric': 'euclidean', 'n_neighbors': 15}),
#  EvalResult(eval_type='NNP', label='nnp-50-noself-euclidean', value=np.float64(0.8485333333333334), info={'metric': 'euclidean', 'n_neighbors': 50}),
#  EvalResult(eval_type='NNP', label='nnp-150-noself-euclidean', value=nan, info={'metric': 'euclidean', 'n_neighbors': 150})]
