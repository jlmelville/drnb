# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
# Out:
# time: 425 ms (started: 2022-11-19 10:54:02 -08:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("umap"),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
)
# Out:
# time: 2.38 ms (started: 2022-11-19 10:54:33 -08:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [10:54:34] INFO     Using experiment name: experiment-20221119185434                                 ]8;id=365932;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=300949;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#41\41]8;;\
#            INFO     Getting dataset s1k                                                              ]8;id=489764;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=535625;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#51\51]8;;\
#            INFO     Embedding                                                                        ]8;id=258849;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=10609;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#54\54]8;;\
#            INFO     Using precomputed knn                                                                ]8;id=143467;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=988806;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#58\58]8;;\
#            INFO     Found pre-calculated neighbors file: nn/s1k.15.euclidean.exact.faiss.idx.npy    ]8;id=206776;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py\__init__.py]8;;\:]8;id=765805;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py#251\251]8;;\
#            INFO     Running UMAP                                                                        ]8;id=675267;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=628021;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#110\110]8;;\
# [10:54:39] INFO     Embedding completed                                                                 ]8;id=520465;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=301760;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#115\115]8;;\
#            INFO     Evaluating                                                                       ]8;id=687348;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=882233;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#65\65]8;;\
#            INFO     rte-5-euclidean                                                                  ]8;id=306045;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=815296;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=26972;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=314129;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=654785;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=565838;file:///home/james/dev/drnb/src/drnb/triplets.py#208\208]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=791502;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=126107;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
# [10:54:40] INFO     rpc-5-euclidean                                                                  ]8;id=495974;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=328223;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=66721;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=247278;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=646811;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=550842;file:///home/james/dev/drnb/src/drnb/triplets.py#208\208]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=756011;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=698272;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Global Score Evaluation                                                          ]8;id=801930;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=613485;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     nnp-[15, 50, 150]-noself-euclidean                                               ]8;id=353651;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=586677;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=516941;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=545570;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#54\54]8;;\
#            INFO     Could not load library with AVX2 support due to:                                   ]8;id=687064;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=314101;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#58\58]8;;\
#                     ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
#            INFO     Loading faiss.                                                                     ]8;id=787538;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=373833;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#64\64]8;;\
#            INFO     Successfully loaded faiss.                                                         ]8;id=152693;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=873095;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#66\66]8;;\
# [10:54:41] INFO     Plotting                                                                         ]8;id=653448;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=993290;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#75\75]8;;\
# time: 7.26 s (started: 2022-11-19 10:54:34 -08:00)

# %% [markdown]
# UMAP parameters:
#
# * `n_neighbors=15`
# * `metric="euclidean"`
# * `metric_kwds=None`
# * `n_epochs=None`: set to `500` if `N < 10000`, `200` otherwise. If `densmap=True` then an extra `200` epochs are added.
# * `learning_rate=1.0`
# * `init="spectral"`: one of `"spectral"` (spectral embedding like a noisy Laplacian Eigenmap) or `"random"` (uniform random sampling between -10 and 10).
# * `min_dist=0.1`
# * `spread=1.0`
# * `n_jobs=-1`
# * `set_op_mix_ratio=1.0`
# * `local_connectivity=1.0`
# * `repulsion_strength=1.0`
# * `negative_sample_rate=5`
# * `a=None`
# * `b=None`
# * `random_state=None`
# * `force_approximation_algorithm=False`: if `True`, then use pynndescent's approximate nearest neighbors even for "small" (`N < 4096`) datasets.
# * `verbose=False`
# * `unique=False`: if `True` then identical points in the input space are represented as one point in the output space (which can avoids some trouble with duplicates having zero distance from each other).
# * `densmap=False`: if `True` then use the `densmap` method.
# * `dens_lambda=2.0`: `densmap` parameter.
# * `dens_frac=0.3`: `densmap` parameter.
# * `dens_var_shift=0.1`: `densmap` parameter.
# * `output_dens=False`: `densmap` parameter: if `True`, export the input and output radii
# * `tqdm_kwds=None`: a dict containing configuration for the progress bar when `verbose=True`. Doesn't seem to work great by default in a notebook, so you can turn it off with `{"disable": True}`.

# %%
s1k_densmap = pl.create_pipeline(
    method=pl.embedder("umap", params=dict(densmap=True, output_dens=True)),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
).run("s1k")
# Out:
# time: 27.5 s (started: 2022-11-19 10:54:52 -08:00)

# %%
iris_umap = pl.create_pipeline(
    method=pl.embedder(
        "umap",
        use_precomputed_knn=False,
        params=dict(
            unique=True,
            random_state=42,
            n_neighbors=50,
            verbose=True,
            tqdm_kwds={"disable": True},
        ),
    ),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
).run("iris")
# Out:
# UMAP(n_neighbors=50, random_state=42, unique=True, verbose=True)
# Unique=True -> Number of data points reduced from  150  to  149
# Most common duplicate is 101  with a count of  2
# Sat Nov 19 11:12:41 2022 Construct fuzzy simplicial set
# Sat Nov 19 11:12:41 2022 Finding Nearest Neighbors
# Sat Nov 19 11:12:43 2022 Finished Nearest Neighbor Search
# Sat Nov 19 11:12:43 2022 Construct embedding
# Sat Nov 19 11:12:44 2022 Finished embedding
# [11:12:44] WARNING  151 nearest neighbors requested but only 150 items are available                  ]8;id=684467;file:///home/james/dev/drnb/src/drnb/eval/nbrpres.py\nbrpres.py]8;;\:]8;id=865332;file:///home/james/dev/drnb/src/drnb/eval/nbrpres.py#56\56]8;;\
# time: 4.86 s (started: 2022-11-19 11:12:41 -08:00)
