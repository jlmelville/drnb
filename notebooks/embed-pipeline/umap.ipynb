# %%
# %load_ext lab_black
# %load_ext autotime
import numpy as np
import pandas as pd
# Out:
# time: 268 ms (started: 2022-11-24 15:27:59 -08:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("umap"),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
)
# Out:
# time: 6.81 s (started: 2022-11-24 15:27:59 -08:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [15:28:06] INFO     Using experiment name: experiment-20221124232806                                 ]8;id=477054;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=620310;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#41\41]8;;\
#            INFO     Getting dataset s1k                                                              ]8;id=424003;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=480962;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#51\51]8;;\
#            INFO     Embedding                                                                        ]8;id=366597;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=407185;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#54\54]8;;\
#            INFO     Using precomputed knn                                                                ]8;id=411936;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=526102;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#97\97]8;;\
#            INFO     Found pre-calculated neighbors file: nn/s1k.15.euclidean.exact.faiss.idx.npy    ]8;id=941592;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py\__init__.py]8;;\:]8;id=251465;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py#256\256]8;;\
#            INFO     Running UMAP                                                                        ]8;id=828227;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=137375;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#156\156]8;;\
# [15:28:10] INFO     Embedding completed                                                                 ]8;id=108401;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=344547;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#161\161]8;;\
#            INFO     Evaluating                                                                       ]8;id=390565;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=150000;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#65\65]8;;\
#            INFO     rte-5-euclidean                                                                  ]8;id=159788;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=365981;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=412634;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=790657;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=543130;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=102;file:///home/james/dev/drnb/src/drnb/triplets.py#208\208]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=826832;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=375216;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
# [15:28:11] INFO     rpc-5-euclidean                                                                  ]8;id=163843;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=917338;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=460797;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=971480;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=142233;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=482682;file:///home/james/dev/drnb/src/drnb/triplets.py#208\208]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=777974;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=829609;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Global Score Evaluation                                                          ]8;id=852048;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=242675;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     nnp-[15, 50, 150]-noself-euclidean                                               ]8;id=712971;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=920071;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=948297;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=351896;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#54\54]8;;\
#            INFO     Could not load library with AVX2 support due to:                                   ]8;id=386106;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=773917;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#58\58]8;;\
#                     ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
#            INFO     Loading faiss.                                                                     ]8;id=21292;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=291139;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#64\64]8;;\
#            INFO     Successfully loaded faiss.                                                         ]8;id=376791;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=975213;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#66\66]8;;\
# [15:28:12] INFO     Plotting                                                                         ]8;id=870537;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=990572;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#75\75]8;;\
# time: 6.98 s (started: 2022-11-24 15:28:06 -08:00)

# %% [markdown]
# UMAP parameters:
#
# * `n_neighbors=15`
# * `metric="euclidean"`
# * `metric_kwds=None`
# * `n_epochs=None`: set to `500` if `N < 10000`, `200` otherwise. If `densmap=True` then an extra `200` epochs are added.
# * `learning_rate=1.0`
# * `init="spectral"`: one of `"spectral"` (spectral embedding like a noisy Laplacian Eigenmap) or `"random"` (uniform random sampling between -10 and 10).
# * `min_dist=0.1`
# * `spread=1.0`
# * `n_jobs=-1`
# * `set_op_mix_ratio=1.0`
# * `local_connectivity=1.0`
# * `repulsion_strength=1.0`
# * `negative_sample_rate=5`
# * `a=None`
# * `b=None`
# * `random_state=None`
# * `force_approximation_algorithm=False`: if `True`, then use pynndescent's approximate nearest neighbors even for "small" (`N < 4096`) datasets.
# * `verbose=False`
# * `unique=False`: if `True` then identical points in the input space are represented as one point in the output space (which can avoids some trouble with duplicates having zero distance from each other).
# * `densmap=False`: if `True` then use the `densmap` method.
# * `dens_lambda=2.0`: `densmap` parameter.
# * `dens_frac=0.3`: `densmap` parameter.
# * `dens_var_shift=0.1`: `densmap` parameter.
# * `output_dens=False`: `densmap` parameter: if `True`, export the input and output radii
# * `tqdm_kwds=None`: a dict containing configuration for the progress bar when `verbose=True`. It doesn't seem to work great in a notebook, so this is disabled by default by `drnb` if `verbose=True` is also present (by forcing `tqdm_kwds={"disable": True}`). If you really want tqdm output when `verbose=True`, explicitly set `tqdm_kwds` in the `params`.

# %%
s1k_densmap = pl.create_pipeline(
    method=pl.embedder("umap", params=dict(densmap=True, output_dens=True)),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
).run("s1k")
# Out:
# time: 27.7 s (started: 2022-11-24 15:28:13 -08:00)

# %%
iris_umap = pl.create_pipeline(
    method=pl.embedder(
        "umap",
        use_precomputed_knn=False,
        params=dict(
            unique=True,
            random_state=42,
            n_neighbors=50,
            verbose=True,
        ),
    ),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
).run("iris")
# Out:
# UMAP(n_neighbors=50, random_state=42, unique=True, verbose=True)
# Unique=True -> Number of data points reduced from  150  to  149
# Most common duplicate is 101  with a count of  2
# Thu Nov 24 15:28:41 2022 Construct fuzzy simplicial set
# Thu Nov 24 15:28:41 2022 Finding Nearest Neighbors
# Thu Nov 24 15:28:43 2022 Finished Nearest Neighbor Search
# Thu Nov 24 15:28:43 2022 Construct embedding
# Thu Nov 24 15:28:44 2022 Finished embedding
# [15:28:44] WARNING  151 nearest neighbors requested but only 150 items are available                  ]8;id=816049;file:///home/james/dev/drnb/src/drnb/eval/nbrpres.py\nbrpres.py]8;;\:]8;id=239150;file:///home/james/dev/drnb/src/drnb/eval/nbrpres.py#56\56]8;;\
# time: 4.44 s (started: 2022-11-24 15:28:41 -08:00)
