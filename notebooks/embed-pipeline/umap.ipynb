# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
# Out:
# time: 277 ms (started: 2022-09-17 13:14:11 -07:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("umap"),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
)
# Out:
# time: 5.57 s (started: 2022-09-17 13:14:24 -07:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [13:14:31] INFO     Getting dataset s1k                                                              ]8;id=131609;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=45194;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#37\37]8;;\
#            INFO     Embedding                                                                        ]8;id=520101;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=286530;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#40\40]8;;\
#            INFO     Using precomputed knn                                                                ]8;id=278643;file:///home/james/dev/drnb/src/drnb/embed/umap.py\umap.py]8;;\:]8;id=403335;file:///home/james/dev/drnb/src/drnb/embed/umap.py#32\32]8;;\
#            INFO     Found pre-calculated neighbors file: nn/s1k.15.euclidean.exact.faiss.idx.npy    ]8;id=430196;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py\__init__.py]8;;\:]8;id=528189;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py#235\235]8;;\
#            INFO     Running UMAP                                                                         ]8;id=303619;file:///home/james/dev/drnb/src/drnb/embed/umap.py\umap.py]8;;\:]8;id=87996;file:///home/james/dev/drnb/src/drnb/embed/umap.py#62\62]8;;\
# [13:14:39] INFO     Embedding completed                                                                  ]8;id=835826;file:///home/james/dev/drnb/src/drnb/embed/umap.py\umap.py]8;;\:]8;id=203416;file:///home/james/dev/drnb/src/drnb/embed/umap.py#67\67]8;;\
#            INFO     Evaluating                                                                       ]8;id=63869;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=409294;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#43\43]8;;\
#            INFO     Random Triplet Evaluation num triplets per point: 5                              ]8;id=546144;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=515536;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=354352;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=546089;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=744368;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=882815;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=316284;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=752887;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Random Pair Correlation num triplets per point: 5                                ]8;id=565587;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=899685;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=51967;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=210645;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=980201;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=361615;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=201836;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=394566;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Global Score Evaluation                                                          ]8;id=591835;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=383960;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Neighbor Preservation for n_neighbors: [15, 50, 150] (excluding self)            ]8;id=243214;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=436598;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=109652;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=992787;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#54\54]8;;\
#            INFO     Could not load library with AVX2 support due to:                                   ]8;id=921247;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=938931;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#58\58]8;;\
#                     ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
#            INFO     Loading faiss.                                                                     ]8;id=208773;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=357094;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#64\64]8;;\
#            INFO     Successfully loaded faiss.                                                         ]8;id=687462;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=917579;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#66\66]8;;\
# [13:14:40] INFO     Plotting                                                                         ]8;id=161863;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=240156;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#46\46]8;;\
#            INFO     Looking for pkl format from data/s1k-target-palette.pkl                         ]8;id=241320;file:///home/james/dev/drnb/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=527339;file:///home/james/dev/drnb/src/drnb/io/__init__.py#151\151]8;;\
#            INFO     Exporting                                                                        ]8;id=669428;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=24495;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#49\49]8;;\
# time: 9.36 s (started: 2022-09-17 13:14:31 -07:00)

# %% [markdown]
# UMAP parameters:
#
# * `n_neighbors=15`
# * `metric="euclidean"`
# * `metric_kwds=None`
# * `n_epochs=None`: set to `500` if `N < 10000`, `200` otherwise. If `densmap=True` then an extra `200` epochs are added.
# * `learning_rate=1.0`
# * `init="spectral"`: one of `"spectral"` (spectral embedding like a noisy Laplacian Eigenmap) or `"random"` (uniform random sampling between -10 and 10).
# * `min_dist=0.1`
# * `spread=1.0`
# * `n_jobs=-1`
# * `set_op_mix_ratio=1.0`
# * `local_connectivity=1.0`
# * `repulsion_strength=1.0`
# * `negative_sample_rate=5`
# * `a=None`
# * `b=None`
# * `random_state=None`
# * `force_approximation_algorithm=False`: if `True`, then use pynndescent's approximate nearest neighbors even for "small" (`N < 4096`) datasets.
# * `verbose=False`
# * `unique=False`: if `True` then identical points in the input space are represented as one point in the output space (which can avoids some trouble with duplicates having zero distance from each other).
# * `densmap=False`: if `True` then use the `densmap` method.
# * `dens_lambda=2.0`: `densmap` parameter.
# * `dens_frac=0.3`: `densmap` parameter.
# * `dens_var_shift=0.1`: `densmap` parameter.
# * `output_dens=False`: `densmap` parameter: if `True`, export the input and output radii
# * `tqdm_kwds=None`: a dict containing configuration for the progress bar when `verbose=True`. Doesn't seem to work great by default in a notebook, so you can turn it off with `{"disable": True}`.

# %%
s1k_densmap = pl.create_pipeline(
    method=pl.embedder("umap", params=dict(densmap=True, output_dens=True)),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
).run("s1k")
# Out:
# time: 36.9 s (started: 2022-09-17 13:15:29 -07:00)

# %%
iris_umap = pl.create_pipeline(
    method=pl.embedder(
        "umap",
        use_precomputed_knn=False,
        params=dict(
            unique=True,
            random_state=42,
            n_neighbors=50,
            verbose=True,
            tqdm_kwds={"disable": True},
        ),
    ),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
).run("iris")
# Out:
# UMAP(n_neighbors=50, random_state=42, unique=True, verbose=True)
# Unique=True -> Number of data points reduced from  150  to  149
# Most common duplicate is 101  with a count of  2
# Sat Sep 17 13:17:58 2022 Construct fuzzy simplicial set
# Sat Sep 17 13:17:58 2022 Finding Nearest Neighbors
# Sat Sep 17 13:17:58 2022 Finished Nearest Neighbor Search
# Sat Sep 17 13:17:58 2022 Construct embedding
# Sat Sep 17 13:17:59 2022 Finished embedding
# [13:17:59] WARNING  151 nearest neighbors requested but only 150 items are available                  ]8;id=718867;file:///home/james/dev/drnb/src/drnb/eval/nbrpres.py\nbrpres.py]8;;\:]8;id=33453;file:///home/james/dev/drnb/src/drnb/eval/nbrpres.py#54\54]8;;\
# time: 1.64 s (started: 2022-09-17 13:17:58 -07:00)
