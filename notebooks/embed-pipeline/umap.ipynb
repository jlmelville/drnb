# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
# Out:
# time: 306 ms (started: 2022-11-19 11:17:22 -08:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("umap"),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
)
# Out:
# time: 7.76 s (started: 2022-11-19 11:17:23 -08:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [11:17:30] INFO     Using experiment name: experiment-20221119191730                                 ]8;id=4931;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=334926;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#41\41]8;;\
#            INFO     Getting dataset s1k                                                              ]8;id=324849;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=573125;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#51\51]8;;\
#            INFO     Embedding                                                                        ]8;id=349118;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=877252;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#54\54]8;;\
#            INFO     Using precomputed knn                                                                ]8;id=56222;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=618322;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#58\58]8;;\
#            INFO     Found pre-calculated neighbors file: nn/s1k.15.euclidean.exact.faiss.idx.npy    ]8;id=449651;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py\__init__.py]8;;\:]8;id=274995;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py#251\251]8;;\
#            INFO     Running UMAP                                                                        ]8;id=11699;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=638603;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#115\115]8;;\
# [11:17:36] INFO     Embedding completed                                                                 ]8;id=566261;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py\umap.py]8;;\:]8;id=552614;file:///home/james/dev/drnb/src/drnb/embed/umap/umap.py#120\120]8;;\
#            INFO     Evaluating                                                                       ]8;id=742060;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=927041;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#65\65]8;;\
#            INFO     rte-5-euclidean                                                                  ]8;id=121384;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=195609;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=997433;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=849354;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=396379;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=548175;file:///home/james/dev/drnb/src/drnb/triplets.py#208\208]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=322835;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=436435;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
# [11:17:37] INFO     rpc-5-euclidean                                                                  ]8;id=653519;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=961385;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=886803;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=324668;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=856133;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=310263;file:///home/james/dev/drnb/src/drnb/triplets.py#208\208]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=100000;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=259126;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Global Score Evaluation                                                          ]8;id=124605;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=781788;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     nnp-[15, 50, 150]-noself-euclidean                                               ]8;id=651699;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=579938;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=861383;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=231428;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#54\54]8;;\
#            INFO     Could not load library with AVX2 support due to:                                   ]8;id=624845;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=805899;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#58\58]8;;\
#                     ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
#            INFO     Loading faiss.                                                                     ]8;id=281134;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=949488;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#64\64]8;;\
#            INFO     Successfully loaded faiss.                                                         ]8;id=836964;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=125156;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#66\66]8;;\
# [11:17:38] INFO     Plotting                                                                         ]8;id=855480;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=378646;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#75\75]8;;\
# time: 9.35 s (started: 2022-11-19 11:17:30 -08:00)

# %% [markdown]
# UMAP parameters:
#
# * `n_neighbors=15`
# * `metric="euclidean"`
# * `metric_kwds=None`
# * `n_epochs=None`: set to `500` if `N < 10000`, `200` otherwise. If `densmap=True` then an extra `200` epochs are added.
# * `learning_rate=1.0`
# * `init="spectral"`: one of `"spectral"` (spectral embedding like a noisy Laplacian Eigenmap) or `"random"` (uniform random sampling between -10 and 10).
# * `min_dist=0.1`
# * `spread=1.0`
# * `n_jobs=-1`
# * `set_op_mix_ratio=1.0`
# * `local_connectivity=1.0`
# * `repulsion_strength=1.0`
# * `negative_sample_rate=5`
# * `a=None`
# * `b=None`
# * `random_state=None`
# * `force_approximation_algorithm=False`: if `True`, then use pynndescent's approximate nearest neighbors even for "small" (`N < 4096`) datasets.
# * `verbose=False`
# * `unique=False`: if `True` then identical points in the input space are represented as one point in the output space (which can avoids some trouble with duplicates having zero distance from each other).
# * `densmap=False`: if `True` then use the `densmap` method.
# * `dens_lambda=2.0`: `densmap` parameter.
# * `dens_frac=0.3`: `densmap` parameter.
# * `dens_var_shift=0.1`: `densmap` parameter.
# * `output_dens=False`: `densmap` parameter: if `True`, export the input and output radii
# * `tqdm_kwds=None`: a dict containing configuration for the progress bar when `verbose=True`. It doesn't seem to work great in a notebook, so this is disabled by default by `drnb` if `verbose=True` is also present (by forcing `tqdm_kwds={"disable": True}`). If you really want tqdm output when `verbose=True`, explicitly set `tqdm_kwds` in the `params`.

# %%
s1k_densmap = pl.create_pipeline(
    method=pl.embedder("umap", params=dict(densmap=True, output_dens=True)),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
).run("s1k")
# Out:
# time: 30.3 s (started: 2022-11-19 11:17:40 -08:00)

# %%
iris_umap = pl.create_pipeline(
    method=pl.embedder(
        "umap",
        use_precomputed_knn=False,
        params=dict(
            unique=True,
            random_state=42,
            n_neighbors=50,
            verbose=True,
        ),
    ),
    eval_metrics=["rte", "rpc", "gs", ("nnp", dict(n_neighbors=[15, 50, 150]))],
).run("iris")
# Out:
# UMAP(n_neighbors=50, random_state=42, unique=True, verbose=True)
# Unique=True -> Number of data points reduced from  150  to  149
# Most common duplicate is 101  with a count of  2
# Sat Nov 19 11:18:10 2022 Construct fuzzy simplicial set
# Sat Nov 19 11:18:10 2022 Finding Nearest Neighbors
# Sat Nov 19 11:18:13 2022 Finished Nearest Neighbor Search
# Sat Nov 19 11:18:13 2022 Construct embedding
# Sat Nov 19 11:18:14 2022 Finished embedding
# [11:18:14] WARNING  151 nearest neighbors requested but only 150 items are available                  ]8;id=559246;file:///home/james/dev/drnb/src/drnb/eval/nbrpres.py\nbrpres.py]8;;\:]8;id=490174;file:///home/james/dev/drnb/src/drnb/eval/nbrpres.py#56\56]8;;\
# time: 4.92 s (started: 2022-11-19 11:18:10 -08:00)
