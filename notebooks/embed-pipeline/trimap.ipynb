# %%
# %load_ext lab_black
# %load_ext autotime
import numpy as np
import pandas as pd
# Out:
# time: 365 ms (started: 2023-07-29 14:40:50 -07:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("trimap"),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(figsize=(6, 4), legend="force"),
)
# Out:
# /home/james/dev/drnb/venv/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/james/dev/drnb/venv/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/james/dev/drnb/venv/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/james/dev/drnb/venv/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# time: 17 s (started: 2023-07-29 14:40:50 -07:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [14:41:07] INFO     Getting dataset s1k                                                              ]8;id=955669;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=25917;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#58\58]8;;\
# [14:41:08] INFO     Embedding                                                                        ]8;id=505773;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=842848;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#61\61]8;;\
#            INFO     Using precomputed knn                                                              ]8;id=882032;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=424110;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#23\23]8;;\
#            INFO     Found pre-calculated neighbors file: nn/s1k.15.euclidean.exact.faiss.idx.npy    ]8;id=652252;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py\__init__.py]8;;\:]8;id=616266;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py#298\298]8;;\
#            INFO     Running TriMap                                                                     ]8;id=892630;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=565714;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#48\48]8;;\
# [14:41:09] INFO     Embedding completed                                                                ]8;id=169818;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=805803;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#63\63]8;;\
#            INFO     Evaluating                                                                       ]8;id=963633;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=574380;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#82\82]8;;\
#            INFO     rte-5-euclidean                                                                  ]8;id=694013;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=537266;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=365964;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=489839;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=71917;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=836586;file:///home/james/dev/drnb/src/drnb/triplets.py#208\208]8;;\
#            INFO     Also found corresponding euclidean distances                                    ]8;id=102156;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=638161;file:///home/james/dev/drnb/src/drnb/triplets.py#211\211]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=82570;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=314872;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
# [14:41:10] INFO     rpc-5-euclidean                                                                  ]8;id=283605;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=117048;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=266840;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=133262;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=672875;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=641660;file:///home/james/dev/drnb/src/drnb/triplets.py#208\208]8;;\
#            INFO     Also found corresponding euclidean distances                                    ]8;id=65504;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=189020;file:///home/james/dev/drnb/src/drnb/triplets.py#211\211]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=290487;file:///home/james/dev/drnb/src/drnb/triplets.py\triplets.py]8;;\:]8;id=491007;file:///home/james/dev/drnb/src/drnb/triplets.py#196\196]8;;\
#            INFO     nnp-[15, 50, 150]-noself-euclidean                                               ]8;id=804909;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=635121;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=696678;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss-1.7.4-py3.10.egg/faiss/loader.py\loader.py]8;;\:]8;id=851538;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss-1.7.4-py3.10.egg/faiss/loader.py#54\54]8;;\
#            INFO     Successfully loaded faiss with AVX2 support.                                       ]8;id=631334;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss-1.7.4-py3.10.egg/faiss/loader.py\loader.py]8;;\:]8;id=716725;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss-1.7.4-py3.10.egg/faiss/loader.py#56\56]8;;\
# [14:41:11] INFO     Plotting                                                                         ]8;id=284615;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=587276;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#92\92]8;;\
# time: 4.81 s (started: 2023-07-29 14:41:07 -07:00)

# %% [markdown]
# TriMap parameters from the [github README](https://github.com/eamid/trimap):
#
# * `n_inliers=12`: number of nearest neighbors.
# * `n_outliers=4`: number of outliers for forming the nearest neighbor triplets.
# * `n_random=3`: number of random triplets per point.
# * `distance="euclidean"`: distance measure, one of: (`"euclidean"` (default), `"manhattan"`, `"angular"` (or `"cosine"`), `"hamming"`).
# * `weight_temp=0.5`: temperature of the logarithm applied to the weights. Larger temperatures generate more compact embeddings.
# * `lr=0.1`: learning rate.
# * `n_iters=400`
# * `apply_pca=True`: whether to apply PCA on the input data. Ignored if `distance="hamming"` or there are fewer than 100 dimensions in the input data. Otherwise, the first 100 components from truncated SVD are extracted. Data is centered. If no PCA is applied then data is scaled to 0-1 globally (columns maintain their ratio of variances) and then mean-centered.
# * `opt_method="dbd"`: optimization method, one of :`"sd"` (steepest descent), `"momentum"` (steepest descent with momentum), `"dbd"` (delta-bar-delta method like t-SNE).
# * `return_seq=False` Store the intermediate results and return the results in a tensor. Coordinates are returned every 10 iterations. It's less easy to control this than with PaCMAP. You can try setting `trimap.trimap_._RETURN_EVERY` to a larger value (e.g. `100` to return every 100 iterations), but from the number of underscores you can see in that expression, I don't think we should rely on that being a stable public API.
# * `verbose=False`
# * `init=None` Initialization: can be one of `"pca"` (the default, also scales the result by `0.01`) or `"random"` (use the t-SNE-style normal distribution with sdev = 1e-4). A matrix of initial coordinates may also be provided.

# %%
embed_snapshot_pl = pl.create_pipeline(
    method=pl.embedder("trimap", params=dict(verbose=True, return_seq=True)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(figsize=(6, 4), legend="force"),
)
embed_snapshot_result = embed_snapshot_pl.run("s1k")
# Out:
# TRIMAP(n_inliers=12, n_outliers=4, n_random=3, distance=euclidean, weight_temp=0.5, lr=0.1, n_iters=400, apply_pca=True, opt_method=dbd, verbose=True, return_seq=True)
# running TriMap on 1000 points with dimension 9
# using pre-computed knn
# running TriMap with dbd
# Iteration:  100 /  400, Loss: 0.292, Violated triplets: 10.6510
# Iteration:  200 /  400, Loss: 0.285, Violated triplets: 10.8020
# Iteration:  300 /  400, Loss: 0.281, Violated triplets: 10.7529
# Iteration:  400 /  400, Loss: 0.279, Violated triplets: 10.7745
# Elapsed time: 0:00:00.931335
# time: 3.52 s (started: 2023-07-29 14:41:12 -07:00)

# %% [markdown]
# Here's a look at the number of snapshots you get back by default:

# %%
embed_snapshot_result["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_10', 'it_20', 'it_30', 'it_40', 'it_50', 'it_60', 'it_70', 'it_80', 'it_90', 'it_100', 'it_110', 'it_120', 'it_130', 'it_140', 'it_150', 'it_160', 'it_170', 'it_180', 'it_190', 'it_200', 'it_210', 'it_220', 'it_230', 'it_240', 'it_250', 'it_260', 'it_270', 'it_280', 'it_290', 'it_300', 'it_310', 'it_320', 'it_330', 'it_340', 'it_350', 'it_360', 'it_370', 'it_380', 'it_390', 'it_400'])
# time: 3.8 ms (started: 2023-07-29 14:41:16 -07:00)

# %% [markdown]
# That's a lot. The current version of TriMap (1.1.4) [has a bug](https://github.com/eamid/trimap/issues/23) which means the initial output at `it_0` isn't correctly returned, so here's iteration 10 instead:

# %%
import drnb.io.dataset as nbdata
import drnb.plot as nbplot

nbplot.sns_embed_plot(
    embed_snapshot_result["snapshots"]["it_10"], nbdata.read_target("s1k")
)
# Out:
# <Axes: >
# time: 1.13 s (started: 2023-07-29 14:41:16 -07:00)

# %% [markdown]
# Here's an example of (unwisely) using the internal `RETURN_EVERY` setting to produce fewer snapshots of the coordinates:

# %%
import trimap

trimap.trimap_._RETURN_EVERY = 100
s1k_trimap_every100 = embed_snapshot_pl.run("s1k")
# Out:
# TRIMAP(n_inliers=12, n_outliers=4, n_random=3, distance=euclidean, weight_temp=0.5, lr=0.1, n_iters=400, apply_pca=True, opt_method=dbd, verbose=True, return_seq=True)
# running TriMap on 1000 points with dimension 9
# using pre-computed knn
# running TriMap with dbd
# Iteration:  100 /  400, Loss: 0.299, Violated triplets: 10.7196
# Iteration:  200 /  400, Loss: 0.293, Violated triplets: 10.8392
# Iteration:  300 /  400, Loss: 0.289, Violated triplets: 10.8804
# Iteration:  400 /  400, Loss: 0.287, Violated triplets: 10.9333
# Elapsed time: 0:00:01.001542
# time: 2.98 s (started: 2023-07-29 14:41:17 -07:00)

# %%
s1k_trimap_every100["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_100', 'it_200', 'it_300', 'it_400'])
# time: 3.57 ms (started: 2023-07-29 14:41:20 -07:00)

# %% [markdown]
# As you can see, we have returned a more manageable set of snapshots. We should remember to change that setting back though:

# %%
trimap.trimap_._RETURN_EVERY = 10
# Out:
# time: 1.63 ms (started: 2023-07-29 14:41:20 -07:00)

# %% [markdown]
# If you are convinced this is a good idea, you may provide a `return_every` argument when creating the embedder and it will set this entry for you and change it back. I make no claim it's foolproof if an exception is thrown in the middle of the calculation. Note that you *don't* pass this parameter to the `params` dictionary as it is not part of the trimap API and trimap won't know what to do with it, i.e. do this:
#
# ```python
# # Good
# nb.embedder("trimap", return_every=200, params=dict(return_seq=True))
# ```
#
# and **do not** do this:
#
# ```python
# # BAD
# nb.embedder("trimap", params=dict(return_seq=True, return_every=200))
# ```

# %%
s1k_trimap_every200 = pl.create_pipeline(
    method=pl.embedder("trimap", return_every=200, params=dict(return_seq=True)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(figsize=(6, 4), legend="force"),
).run("s1k")
# Out:
# time: 2.96 s (started: 2023-07-29 14:41:20 -07:00)

# %% [markdown]
# Check it worked:

# %%
s1k_trimap_every200["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_200', 'it_400'])
# time: 3.86 ms (started: 2023-07-29 14:41:23 -07:00)

# %% [markdown]
# And `RETURN_EVERY` should be back to normal:

# %%
trimap.trimap_._RETURN_EVERY
# Out:
# 10
# time: 8.58 ms (started: 2023-07-29 14:41:23 -07:00)

# %% [markdown]
# As a convenience, `standard_pipeline` lets you separate special `drnb` keywords from the passed-through algorithm parameters:

# %%
s1k_trimap_every200 = pl.standard_pipeline(
    method=("trimap", dict(return_every=200)),
    params=dict(return_seq=True),
).run("s1k")
# Out:
# time: 2.8 s (started: 2023-07-29 14:42:41 -07:00)

# %%
s1k_trimap_every200["snapshots"].keys(), trimap.trimap_._RETURN_EVERY
# Out:
# (dict_keys(['it_0', 'it_200', 'it_400']), 10)
# time: 5.91 ms (started: 2023-07-29 14:42:57 -07:00)
