# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
# Out:
# time: 294 ms (started: 2022-09-17 14:14:27 -07:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("trimap"),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
)
# Out:
# time: 16.1 s (started: 2022-09-17 14:14:27 -07:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [14:14:45] INFO     Getting dataset s1k                                                              ]8;id=506810;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=652123;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#37\37]8;;\
#            INFO     Embedding                                                                        ]8;id=920613;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=994627;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#40\40]8;;\
#            INFO     Using precomputed knn                                                              ]8;id=371106;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=778600;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#23\23]8;;\
#            INFO     Found pre-calculated neighbors file: nn/s1k.15.euclidean.exact.faiss.idx.npy    ]8;id=296939;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py\__init__.py]8;;\:]8;id=680377;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py#235\235]8;;\
#            INFO     Running TriMap                                                                     ]8;id=534953;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=340000;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#48\48]8;;\
# [14:14:48] INFO     Embedding completed                                                                ]8;id=804295;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=273259;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#63\63]8;;\
#            INFO     Evaluating                                                                       ]8;id=978695;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=239474;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#43\43]8;;\
#            INFO     Random Triplet Evaluation num triplets per point: 5                              ]8;id=281893;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=332060;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=458869;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=646696;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=86193;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=785348;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=942963;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=415773;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Random Pair Correlation num triplets per point: 5                                ]8;id=903765;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=177264;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=705206;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=185967;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=354290;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=107547;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=813035;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=919809;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Neighbor Preservation for n_neighbors: [15, 50, 150] (excluding self)            ]8;id=523945;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=989974;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=854538;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=370986;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#54\54]8;;\
#            INFO     Could not load library with AVX2 support due to:                                   ]8;id=211756;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=742921;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#58\58]8;;\
#                     ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
#            INFO     Loading faiss.                                                                     ]8;id=507021;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=305655;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#64\64]8;;\
#            INFO     Successfully loaded faiss.                                                         ]8;id=19402;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=331767;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#66\66]8;;\
# [14:14:49] INFO     Plotting                                                                         ]8;id=878336;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=409162;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#46\46]8;;\
#            INFO     Looking for pkl format from data/s1k-target-palette.pkl                         ]8;id=497968;file:///home/james/dev/drnb/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=878319;file:///home/james/dev/drnb/src/drnb/io/__init__.py#151\151]8;;\
#            INFO     Exporting                                                                        ]8;id=453816;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=907709;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#49\49]8;;\
# time: 4.57 s (started: 2022-09-17 14:14:45 -07:00)

# %% [markdown]
# TriMap parameters from the [github README](https://github.com/eamid/trimap):
#
# * `n_inliers=12`: number of nearest neighbors.
# * `n_outliers=4`: number of outliers for forming the nearest neighbor triplets.
# * `n_random=3`: number of random triplets per point.
# * `distance="euclidean"`: distance measure, one of: (`"euclidean"` (default), `"manhattan"`, `"angular"` (or `"cosine"`), `"hamming"`).
# * `weight_temp=0.5`: temperature of the logarithm applied to the weights. Larger temperatures generate more compact embeddings.
# * `lr=0.1`: learning rate.
# * `n_iters=400`
# * `apply_pca=True`: whether to apply PCA on the input data. Ignored if `distance="hamming"` or there are fewer than 100 dimensions in the input data. Otherwise, the first 100 components from truncated SVD are extracted. Data is centered. If no PCA is applied then data is scaled to 0-1 globally (columns maintain their ratio of variances) and then mean-centered.
# * `opt_method="dbd"`: optimization method, one of :`"sd"` (steepest descent), `"momentum"` (steepest descent with momentum), `"dbd"` (delta-bar-delta method like t-SNE).
# * `return_seq=False` Store the intermediate results and return the results in a tensor. Coordinates are returned every 10 iterations. It's less easy to control this than with PaCMAP. You can try setting `trimap.trimap_._RETURN_EVERY` to a larger value (e.g. `100` to return every 100 iterations), but from the number of underscores you can see in that expression, I don't think we should rely on that being a stable public API.
# * `verbose=False`
# * `init=None` Initialization: can be one of `"pca"` (the default, also scales the result by `0.01`) or `"random"` (use the t-SNE-style normal distribution with sdev = 1e-4). A matrix of initial coordinates may also be provided.

# %%
embed_snapshot_pl = pl.create_pipeline(
    method=pl.embedder("trimap", params=dict(verbose=True, return_seq=True)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
)
embed_snapshot_result = embed_snapshot_pl.run("s1k")
# Out:
# TRIMAP(n_inliers=12, n_outliers=4, n_random=3, distance=euclidean, weight_temp=0.5, lr=0.1, n_iters=400, apply_pca=True, opt_method=dbd, verbose=True, return_seq=True)
# running TriMap on 1000 points with dimension 9
# using pre-computed knn
# running TriMap with dbd
# Iteration:  100 /  400, Loss: 0.283, Violated triplets: 10.6137
# Iteration:  200 /  400, Loss: 0.277, Violated triplets: 10.6745
# Iteration:  300 /  400, Loss: 0.274, Violated triplets: 10.7647
# Iteration:  400 /  400, Loss: 0.272, Violated triplets: 10.8471
# Elapsed time: 0:00:02.885482
# time: 3.93 s (started: 2022-09-17 14:14:56 -07:00)

# %% [markdown]
# Here's a look at the number of snapshots you get back by default:

# %%
embed_snapshot_result["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_10', 'it_20', 'it_30', 'it_40', 'it_50', 'it_60', 'it_70', 'it_80', 'it_90', 'it_100', 'it_110', 'it_120', 'it_130', 'it_140', 'it_150', 'it_160', 'it_170', 'it_180', 'it_190', 'it_200', 'it_210', 'it_220', 'it_230', 'it_240', 'it_250', 'it_260', 'it_270', 'it_280', 'it_290', 'it_300', 'it_310', 'it_320', 'it_330', 'it_340', 'it_350', 'it_360', 'it_370', 'it_380', 'it_390', 'it_400'])
# time: 3.55 ms (started: 2022-09-17 14:15:03 -07:00)

# %% [markdown]
# That's a lot. The current version of TriMap (1.1.4) [has a bug](https://github.com/eamid/trimap/issues/23) which means the initial output at `it_0` isn't correctly returned, so here's iteration 10 instead:

# %%
import drnb.plot as nbplot
import drnb.io.dataset as nbdata

nbplot.sns_embed_plot(
    embed_snapshot_result["snapshots"]["it_10"], nbdata.read_target("s1k")
)
# Out:
# time: 517 ms (started: 2022-09-17 14:15:04 -07:00)

# %% [markdown]
# Here's an example of (unwisely) using the internal `RETURN_EVERY` setting to produce fewer snapshots of the coordinates:

# %%
import trimap

trimap.trimap_._RETURN_EVERY = 100
s1k_trimap_every100 = embed_snapshot_pl.run("s1k")
# Out:
# TRIMAP(n_inliers=12, n_outliers=4, n_random=3, distance=euclidean, weight_temp=0.5, lr=0.1, n_iters=400, apply_pca=True, opt_method=dbd, verbose=True, return_seq=True)
# running TriMap on 1000 points with dimension 9
# using pre-computed knn
# running TriMap with dbd
# Iteration:  100 /  400, Loss: 0.289, Violated triplets: 10.6529
# Iteration:  200 /  400, Loss: 0.282, Violated triplets: 10.7137
# Iteration:  300 /  400, Loss: 0.278, Violated triplets: 10.8941
# Iteration:  400 /  400, Loss: 0.276, Violated triplets: 10.8804
# Elapsed time: 0:00:02.861123
# time: 3.91 s (started: 2022-09-17 14:15:05 -07:00)

# %%
s1k_trimap_every100["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_100', 'it_200', 'it_300', 'it_400'])
# time: 4.46 ms (started: 2022-09-17 14:15:10 -07:00)

# %% [markdown]
# As you can see, we have returned a more manageable set of snapshots. We should remember to change that setting back though:

# %%
trimap.trimap_._RETURN_EVERY = 10
# Out:
# time: 1.41 ms (started: 2022-09-17 14:15:10 -07:00)

# %% [markdown]
# If you are convinced this is a good idea, you may provide a `return_every` argument when creating the embedder and it will set this entry for you and change it back. I make no claim it's foolproof if an exception is thrown in the middle of the calculation. Note that you *don't* pass this parameter to the `params` dictionary as it is not part of the trimap API and trimap won't know what to do with it, i.e. do this:
#
# ```python
# # Good
# nb.embedder("trimap", return_every=200, params=dict(return_seq=True))
# ```
#
# and **do not** do this:
#
# ```python
# # BAD
# nb.embedder("trimap", params=dict(return_seq=True, return_every=200))
# ```

# %%
s1k_trimap_every200 = pl.create_pipeline(
    method=pl.embedder("trimap", return_every=200, params=dict(return_seq=True)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
).run("s1k")
# Out:
# time: 3.55 s (started: 2022-09-17 14:15:11 -07:00)

# %% [markdown]
# Check it worked:

# %%
s1k_trimap_every200["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_200', 'it_400'])
# time: 4.48 ms (started: 2022-09-17 14:15:15 -07:00)

# %% [markdown]
# And `RETURN_EVERY` should be back to normal:

# %%
trimap.trimap_._RETURN_EVERY
# Out:
# 10
# time: 6.22 ms (started: 2022-09-17 14:15:15 -07:00)
