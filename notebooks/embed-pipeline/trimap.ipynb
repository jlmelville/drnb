# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
# Out:
# time: 245 ms (started: 2022-10-01 14:48:02 -07:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("trimap"),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(figsize=(6, 4), legend="force"),
)
# Out:
# time: 12.8 s (started: 2022-10-01 14:48:03 -07:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [14:48:15] INFO     Using experiment name: experiment-20221001214815                                 ]8;id=192610;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=759586;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#42\42]8;;\
#            INFO     Getting dataset s1k                                                              ]8;id=268559;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=280816;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#52\52]8;;\
# [14:48:16] INFO     Embedding                                                                        ]8;id=214625;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=554303;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#55\55]8;;\
#            INFO     Using precomputed knn                                                              ]8;id=692081;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=291366;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#23\23]8;;\
#            INFO     Found pre-calculated neighbors file: nn/s1k.15.euclidean.exact.faiss.idx.npy    ]8;id=383541;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py\__init__.py]8;;\:]8;id=374556;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py#249\249]8;;\
#            INFO     Running TriMap                                                                     ]8;id=176333;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=787924;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#48\48]8;;\
# [14:48:17] INFO     Embedding completed                                                                ]8;id=399331;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=362484;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#63\63]8;;\
#            INFO     Evaluating                                                                       ]8;id=173587;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=650931;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#58\58]8;;\
#            INFO     rte-5-euclidean                                                                  ]8;id=792035;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=532996;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=471610;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=170253;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#181\181]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=66558;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=981694;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#193\193]8;;\
#            INFO     rpc-5-euclidean                                                                  ]8;id=671019;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=781282;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=46432;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=727774;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#181\181]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.npy                                 ]8;id=896187;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=694814;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#193\193]8;;\
#            INFO     nnp-[15, 50, 150]-noself-euclidean                                               ]8;id=430386;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=140238;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#13\13]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=897243;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=937607;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#54\54]8;;\
#            INFO     Could not load library with AVX2 support due to:                                   ]8;id=921633;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=698482;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#58\58]8;;\
#                     ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
#            INFO     Loading faiss.                                                                     ]8;id=720618;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=298900;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#64\64]8;;\
#            INFO     Successfully loaded faiss.                                                         ]8;id=457260;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=32510;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#66\66]8;;\
# [14:48:18] INFO     Plotting                                                                         ]8;id=629049;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=814666;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#70\70]8;;\
# time: 2.86 s (started: 2022-10-01 14:48:15 -07:00)

# %% [markdown]
# TriMap parameters from the [github README](https://github.com/eamid/trimap):
#
# * `n_inliers=12`: number of nearest neighbors.
# * `n_outliers=4`: number of outliers for forming the nearest neighbor triplets.
# * `n_random=3`: number of random triplets per point.
# * `distance="euclidean"`: distance measure, one of: (`"euclidean"` (default), `"manhattan"`, `"angular"` (or `"cosine"`), `"hamming"`).
# * `weight_temp=0.5`: temperature of the logarithm applied to the weights. Larger temperatures generate more compact embeddings.
# * `lr=0.1`: learning rate.
# * `n_iters=400`
# * `apply_pca=True`: whether to apply PCA on the input data. Ignored if `distance="hamming"` or there are fewer than 100 dimensions in the input data. Otherwise, the first 100 components from truncated SVD are extracted. Data is centered. If no PCA is applied then data is scaled to 0-1 globally (columns maintain their ratio of variances) and then mean-centered.
# * `opt_method="dbd"`: optimization method, one of :`"sd"` (steepest descent), `"momentum"` (steepest descent with momentum), `"dbd"` (delta-bar-delta method like t-SNE).
# * `return_seq=False` Store the intermediate results and return the results in a tensor. Coordinates are returned every 10 iterations. It's less easy to control this than with PaCMAP. You can try setting `trimap.trimap_._RETURN_EVERY` to a larger value (e.g. `100` to return every 100 iterations), but from the number of underscores you can see in that expression, I don't think we should rely on that being a stable public API.
# * `verbose=False`
# * `init=None` Initialization: can be one of `"pca"` (the default, also scales the result by `0.01`) or `"random"` (use the t-SNE-style normal distribution with sdev = 1e-4). A matrix of initial coordinates may also be provided.

# %%
embed_snapshot_pl = pl.create_pipeline(
    method=pl.embedder("trimap", params=dict(verbose=True, return_seq=True)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(figsize=(6, 4), legend="force"),
)
embed_snapshot_result = embed_snapshot_pl.run("s1k")
# Out:
# TRIMAP(n_inliers=12, n_outliers=4, n_random=3, distance=euclidean, weight_temp=0.5, lr=0.1, n_iters=400, apply_pca=True, opt_method=dbd, verbose=True, return_seq=True)
# running TriMap on 1000 points with dimension 9
# using pre-computed knn
# running TriMap with dbd
# Iteration:  100 /  400, Loss: 0.292, Violated triplets: 10.6980
# Iteration:  200 /  400, Loss: 0.286, Violated triplets: 10.7922
# Iteration:  300 /  400, Loss: 0.283, Violated triplets: 10.8784
# Iteration:  400 /  400, Loss: 0.281, Violated triplets: 10.9412
# Elapsed time: 0:00:01.176850
# time: 2.63 s (started: 2022-10-01 14:48:18 -07:00)

# %% [markdown]
# Here's a look at the number of snapshots you get back by default:

# %%
embed_snapshot_result["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_10', 'it_20', 'it_30', 'it_40', 'it_50', 'it_60', 'it_70', 'it_80', 'it_90', 'it_100', 'it_110', 'it_120', 'it_130', 'it_140', 'it_150', 'it_160', 'it_170', 'it_180', 'it_190', 'it_200', 'it_210', 'it_220', 'it_230', 'it_240', 'it_250', 'it_260', 'it_270', 'it_280', 'it_290', 'it_300', 'it_310', 'it_320', 'it_330', 'it_340', 'it_350', 'it_360', 'it_370', 'it_380', 'it_390', 'it_400'])
# time: 3.43 ms (started: 2022-10-01 14:48:21 -07:00)

# %% [markdown]
# That's a lot. The current version of TriMap (1.1.4) [has a bug](https://github.com/eamid/trimap/issues/23) which means the initial output at `it_0` isn't correctly returned, so here's iteration 10 instead:

# %%
import drnb.plot as nbplot
import drnb.io.dataset as nbdata

nbplot.sns_embed_plot(
    embed_snapshot_result["snapshots"]["it_10"], nbdata.read_target("s1k")
)
# Out:
# <AxesSubplot:>
# time: 356 ms (started: 2022-10-01 14:48:21 -07:00)

# %% [markdown]
# Here's an example of (unwisely) using the internal `RETURN_EVERY` setting to produce fewer snapshots of the coordinates:

# %%
import trimap

trimap.trimap_._RETURN_EVERY = 100
s1k_trimap_every100 = embed_snapshot_pl.run("s1k")
# Out:
# TRIMAP(n_inliers=12, n_outliers=4, n_random=3, distance=euclidean, weight_temp=0.5, lr=0.1, n_iters=400, apply_pca=True, opt_method=dbd, verbose=True, return_seq=True)
# running TriMap on 1000 points with dimension 9
# using pre-computed knn
# running TriMap with dbd
# Iteration:  100 /  400, Loss: 0.291, Violated triplets: 10.7373
# Iteration:  200 /  400, Loss: 0.284, Violated triplets: 10.7255
# Iteration:  300 /  400, Loss: 0.281, Violated triplets: 10.8275
# Iteration:  400 /  400, Loss: 0.279, Violated triplets: 10.8255
# Elapsed time: 0:00:01.241104
# time: 1.98 s (started: 2022-10-01 14:48:21 -07:00)

# %%
s1k_trimap_every100["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_100', 'it_200', 'it_300', 'it_400'])
# time: 3.94 ms (started: 2022-10-01 14:48:23 -07:00)

# %% [markdown]
# As you can see, we have returned a more manageable set of snapshots. We should remember to change that setting back though:

# %%
trimap.trimap_._RETURN_EVERY = 10
# Out:
# time: 2.21 ms (started: 2022-10-01 14:48:23 -07:00)

# %% [markdown]
# If you are convinced this is a good idea, you may provide a `return_every` argument when creating the embedder and it will set this entry for you and change it back. I make no claim it's foolproof if an exception is thrown in the middle of the calculation. Note that you *don't* pass this parameter to the `params` dictionary as it is not part of the trimap API and trimap won't know what to do with it, i.e. do this:
#
# ```python
# # Good
# nb.embedder("trimap", return_every=200, params=dict(return_seq=True))
# ```
#
# and **do not** do this:
#
# ```python
# # BAD
# nb.embedder("trimap", params=dict(return_seq=True, return_every=200))
# ```

# %%
s1k_trimap_every200 = pl.create_pipeline(
    method=pl.embedder("trimap", return_every=200, params=dict(return_seq=True)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(figsize=(6, 4), legend="force"),
).run("s1k")
# Out:
# time: 1.79 s (started: 2022-10-01 14:48:23 -07:00)

# %% [markdown]
# Check it worked:

# %%
s1k_trimap_every200["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_200', 'it_400'])
# time: 3.6 ms (started: 2022-10-01 14:48:25 -07:00)

# %% [markdown]
# And `RETURN_EVERY` should be back to normal:

# %%
trimap.trimap_._RETURN_EVERY
# Out:
# 10
# time: 3.64 ms (started: 2022-10-01 14:48:25 -07:00)
