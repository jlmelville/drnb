# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
# Out:
# time: 286 ms (started: 2022-09-17 12:59:24 -07:00)

# %%
import drnb.embed.pipeline as pl

embed_pipeline = pl.create_pipeline(
    method=pl.embedder("trimap"),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    verbose=True,
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
)
# Out:
# time: 15.9 s (started: 2022-09-17 12:59:42 -07:00)

# %%
embed_result = embed_pipeline.run("s1k")
# Out:
# [13:00:00] INFO     Getting dataset s1k                                                              ]8;id=396866;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=795624;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#37\37]8;;\
#            INFO     Embedding                                                                        ]8;id=820379;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=830355;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#40\40]8;;\
#            INFO     Running TriMap                                                                     ]8;id=56223;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=247696;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#32\32]8;;\
# [13:00:03] INFO     Embedding completed                                                                ]8;id=830488;file:///home/james/dev/drnb/src/drnb/embed/trimap.py\trimap.py]8;;\:]8;id=589691;file:///home/james/dev/drnb/src/drnb/embed/trimap.py#47\47]8;;\
#            INFO     Evaluating                                                                       ]8;id=620387;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=682369;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#43\43]8;;\
#            INFO     Random Triplet Evaluation num triplets per point: 5                              ]8;id=14780;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=619305;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=125982;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=374965;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=115633;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=599393;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
#            INFO     Also found corresponding l2 distances                                           ]8;id=53743;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=377145;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Random Pair Correlation num triplets per point: 5                                ]8;id=349192;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=514488;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Looking for precomputed triplets                                                ]8;id=12367;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=988343;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#149\149]8;;\
#            INFO     Using triplets from triplets/s1k.5.1337.idx.csv                                 ]8;id=286910;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=951131;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#160\160]8;;\
# [13:00:04] INFO     Also found corresponding l2 distances                                           ]8;id=500142;file:///home/james/dev/drnb/src/drnb/eval/triplets.py\triplets.py]8;;\:]8;id=142719;file:///home/james/dev/drnb/src/drnb/eval/triplets.py#163\163]8;;\
#            INFO     Neighbor Preservation for n_neighbors: [15, 50, 150] (excluding self)            ]8;id=710568;file:///home/james/dev/drnb/src/drnb/eval/__init__.py\__init__.py]8;;\:]8;id=904773;file:///home/james/dev/drnb/src/drnb/eval/__init__.py#10\10]8;;\
#            INFO     Loading faiss with AVX2 support.                                                   ]8;id=9312;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=912519;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#54\54]8;;\
#            INFO     Could not load library with AVX2 support due to:                                   ]8;id=543008;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=634239;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#58\58]8;;\
#                     ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
#            INFO     Loading faiss.                                                                     ]8;id=349330;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=628235;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#64\64]8;;\
#            INFO     Successfully loaded faiss.                                                         ]8;id=490412;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py\loader.py]8;;\:]8;id=798338;file:///home/james/dev/drnb/venv/lib/python3.10/site-packages/faiss/loader.py#66\66]8;;\
#            INFO     Plotting                                                                         ]8;id=761916;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=110731;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#46\46]8;;\
#            INFO     Looking for pkl format from data/s1k-target-palette.pkl                         ]8;id=801580;file:///home/james/dev/drnb/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=937205;file:///home/james/dev/drnb/src/drnb/io/__init__.py#151\151]8;;\
# [13:00:05] INFO     Exporting                                                                        ]8;id=959678;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py\pipeline.py]8;;\:]8;id=607732;file:///home/james/dev/drnb/src/drnb/embed/pipeline.py#49\49]8;;\
# time: 4.68 s (started: 2022-09-17 13:00:00 -07:00)

# %% [markdown]
# TriMap parameters from the [github README](https://github.com/eamid/trimap):
#
# * `n_inliers=12`: number of nearest neighbors.
# * `n_outliers=4`: number of outliers for forming the nearest neighbor triplets.
# * `n_random=3`: number of random triplets per point.
# * `distance="euclidean"`: distance measure, one of: (`"euclidean"` (default), `"manhattan"`, `"angular"` (or `"cosine"`), `"hamming"`).
# * `weight_temp=0.5`: temperature of the logarithm applied to the weights. Larger temperatures generate more compact embeddings.
# * `lr=0.1`: learning rate.
# * `n_iters=400`
# * `apply_pca=True`: whether to apply PCA on the input data. Ignored if `distance="hamming"` or there are fewer than 100 dimensions in the input data. Otherwise, the first 100 components from truncated SVD are extracted. Data is centered. If no PCA is applied then data is scaled to 0-1 globally (columns maintain their ratio of variances) and then mean-centered.
# * `opt_method="dbd"`: optimization method, one of :`"sd"` (steepest descent), `"momentum"` (steepest descent with momentum), `"dbd"` (delta-bar-delta method like t-SNE).
# * `return_seq=False` Store the intermediate results and return the results in a tensor. Coordinates are returned every 10 iterations. It's less easy to control this than with PaCMAP. You can try setting `trimap.trimap_._RETURN_EVERY` to a larger value (e.g. `100` to return every 100 iterations), but from the number of underscores you can see in that expression, I don't think we should rely on that being a stable public API.
# * `verbose=False`
# * `init=None` Initialization: can be one of `"pca"` (the default, also scales the result by `0.01`) or `"random"` (use the t-SNE-style normal distribution with sdev = 1e-4). A matrix of initial coordinates may also be provided.

# %%
embed_snapshot_pl = pl.create_pipeline(
    method=pl.embedder("trimap", params=dict(verbose=True, return_seq=True)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
)
embed_snapshot_result = embed_snapshot_pl.run("s1k")
# Out:
# TRIMAP(n_inliers=12, n_outliers=4, n_random=3, distance=euclidean, weight_temp=0.5, lr=0.1, n_iters=400, apply_pca=True, opt_method=dbd, verbose=True, return_seq=True)
# running TriMap on 1000 points with dimension 9
# pre-processing
# found nearest neighbors
# sampled triplets
# running TriMap with dbd
# Iteration:  100 /  400, Loss: 0.242, Violated triplets: 11.2608
# Iteration:  200 /  400, Loss: 0.236, Violated triplets: 11.1608
# Iteration:  300 /  400, Loss: 0.233, Violated triplets: 11.2314
# Iteration:  400 /  400, Loss: 0.231, Violated triplets: 11.2941
# Elapsed time: 0:00:03.091564
# time: 5.12 s (started: 2022-09-17 13:05:19 -07:00)

# %% [markdown]
# Here's a look at the number of snapshots you get back by default:

# %%
embed_snapshot_result["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_10', 'it_20', 'it_30', 'it_40', 'it_50', 'it_60', 'it_70', 'it_80', 'it_90', 'it_100', 'it_110', 'it_120', 'it_130', 'it_140', 'it_150', 'it_160', 'it_170', 'it_180', 'it_190', 'it_200', 'it_210', 'it_220', 'it_230', 'it_240', 'it_250', 'it_260', 'it_270', 'it_280', 'it_290', 'it_300', 'it_310', 'it_320', 'it_330', 'it_340', 'it_350', 'it_360', 'it_370', 'it_380', 'it_390', 'it_400'])
# time: 3.2 ms (started: 2022-09-17 13:02:00 -07:00)

# %% [markdown]
# That's a lot. The current version of TriMap (1.1.4) [has a bug](https://github.com/eamid/trimap/issues/23) which means the initial output at `it_0` isn't correctly returned, so here's iteration 10 instead:

# %%
import drnb.plot as nbplot
import drnb.io.dataset as nbdata

nbplot.sns_embed_plot(
    embed_snapshot_result["snapshots"]["it_10"], nbdata.read_target("s1k")
)
# Out:
# time: 454 ms (started: 2022-09-17 13:04:15 -07:00)

# %% [markdown]
# Here's an example of (unwisely) using the internal `RETURN_EVERY` setting to produce fewer snapshots of the coordinates:

# %%
import trimap

trimap.trimap_._RETURN_EVERY = 100
s1k_trimap_every100 = embed_snapshot_pl.run("s1k")
# Out:
# TRIMAP(n_inliers=12, n_outliers=4, n_random=3, distance=euclidean, weight_temp=0.5, lr=0.1, n_iters=400, apply_pca=True, opt_method=dbd, verbose=True, return_seq=True)
# running TriMap on 1000 points with dimension 9
# pre-processing
# found nearest neighbors
# sampled triplets
# running TriMap with dbd
# Iteration:  100 /  400, Loss: 0.240, Violated triplets: 11.2627
# Iteration:  200 /  400, Loss: 0.233, Violated triplets: 11.1412
# Iteration:  300 /  400, Loss: 0.229, Violated triplets: 11.3059
# Iteration:  400 /  400, Loss: 0.227, Violated triplets: 11.3431
# Elapsed time: 0:00:02.376227
# time: 3.32 s (started: 2022-09-17 13:05:46 -07:00)

# %%
s1k_trimap_every100["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_100', 'it_200', 'it_300', 'it_400'])
# time: 4.44 ms (started: 2022-09-17 13:05:51 -07:00)

# %% [markdown]
# As you can see, we have returned a more manageable set of snapshots. We should remember to change that setting back though:

# %%
trimap.trimap_._RETURN_EVERY = 10
# Out:
# time: 1.72 ms (started: 2022-09-17 13:05:58 -07:00)

# %% [markdown]
# If you are convinced this is a good idea, you may provide a `return_every` argument when creating the embedder and it will set this entry for you and change it back. I make no claim it's foolproof if an exception is thrown in the middle of the calculation. Note that you *don't* pass this parameter to the `params` dictionary as it is not part of the trimap API and trimap won't know what to do with it, i.e. do this:
#
# ```python
# # Good
# nb.embedder("trimap", return_every=200, params=dict(return_seq=True))
# ```
#
# and **do not** do this:
#
# ```python
# # BAD
# nb.embedder("trimap", params=dict(return_seq=True, return_every=200))
# ```

# %%
s1k_trimap_every200 = pl.create_pipeline(
    method=pl.embedder("trimap", return_every=200, params=dict(return_seq=True)),
    eval_metrics=["rte", "rpc", ("nnp", dict(n_neighbors=[15, 50, 150]))],
    plot=dict(cex=10, alpha_scale=1, figsize=(6, 4), legend="force"),
).run("s1k")
# Out:
# time: 5.46 s (started: 2022-09-17 13:07:18 -07:00)

# %% [markdown]
# Check it worked:

# %%
s1k_trimap_every200["snapshots"].keys()
# Out:
# dict_keys(['it_0', 'it_200', 'it_400'])
# time: 4.62 ms (started: 2022-09-17 13:07:27 -07:00)

# %% [markdown]
# And `RETURN_EVERY` should be back to normal:

# %%
trimap.trimap_._RETURN_EVERY
# Out:
# 10
# time: 4.24 ms (started: 2022-09-17 13:07:28 -07:00)
