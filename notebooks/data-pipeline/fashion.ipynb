# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import fetch_openml

# %%
fashion = fetch_openml("Fashion-MNIST")

# %% [markdown]
# The version downloaded from OpenML doesn't contain the description field, so let's add it here:

# %%
fashion.target
# Out:
# 0        9
# 1        0
# 2        0
# 3        3
# 4        0
#         ..
# 69995    9
# 69996    1
# 69997    8
# 69998    1
# 69999    5
# Name: class, Length: 70000, dtype: category
# Categories (10, object): ['0', '1', '2', '3', ..., '6', '7', '8', '9']

# %%
isinstance(fashion.target, pd.Series)
# Out:
# True

# %%
from drnb.util import codes_to_categories

classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot",
]
description = codes_to_categories(fashion.target, classes, col_name="description")
description
# Out:
# 0         Ankle boot
# 1        T-shirt/top
# 2        T-shirt/top
# 3              Dress
# 4        T-shirt/top
#             ...
# 69995     Ankle boot
# 69996        Trouser
# 69997            Bag
# 69998        Trouser
# 69999         Sandal
# Name: description, Length: 70000, dtype: category
# Categories (10, object): ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', ..., 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
target = pd.concat(
    [
        fashion.target,
        description,
    ],
    axis=1,
)
target
# Out:
#       class  description
# 0         9   Ankle boot
# 1         0  T-shirt/top
# 2         0  T-shirt/top
# 3         3        Dress
# 4         0  T-shirt/top
# ...     ...          ...
# 69995     9   Ankle boot
# 69996     1      Trouser
# 69997     8          Bag
# 69998     1      Trouser
# 69999     5       Sandal
#
# [70000 rows x 2 columns]

# %%
from drnb.io.pipeline import create_default_pipeline

data_result = create_default_pipeline(check_for_duplicates=True).run(
    "fashion",
    data=fashion.data,
    target=target,
    tags=["image"],
    url="https://github.com/zalandoresearch/fashion-mnist",
    verbose=True,
)
# Out:
# [21:42:01] INFO     Requesting one extra neighbor to account for self-neighbor        ]8;id=871397;file:///home/james/dev/drnb-plugin/src/drnb/neighbors/compute.py\compute.py]8;;\:]8;id=462203;file:///home/james/dev/drnb-plugin/src/drnb/neighbors/compute.py#613\613]8;;\
#            INFO     Initial data shape: (70000, 784)                                  ]8;id=446644;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=746723;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#83\83]8;;\
#            INFO     Keeping all columns                                             ]8;id=696351;file:///home/james/dev/drnb-plugin/src/drnb/preprocess.py\preprocess.py]8;;\:]8;id=537482;file:///home/james/dev/drnb-plugin/src/drnb/preprocess.py#90\90]8;;\
#            INFO     Data shape after filtering columns: (70000, 784)                 ]8;id=398033;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=986856;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#164\164]8;;\
#            INFO     Removing rows with NAs                                           ]8;id=737475;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=913524;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#145\145]8;;\
#            INFO     Data shape after filtering NAs: (70000, 784)                     ]8;id=978735;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=318035;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#156\156]8;;\
# [21:42:05] INFO     Checked for duplicates: found 0                                  ]8;id=396081;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=167498;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#172\172]8;;\
#            INFO     Converting to numpy with {'dtype': 'float32', 'layout': 'c'}     ]8;id=144735;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=721013;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#187\187]8;;\
# [21:42:06] INFO     Writing data for fashion                                         ]8;id=627890;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=33283;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#298\298]8;;\
#            INFO     Exporting data of type ndarray to npy                            ]8;id=21265;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=39021;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#659\659]8;;\
# [21:42:07] INFO     Exporting data of type ndarray to csv                            ]8;id=658034;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=865157;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#659\659]8;;\
# [21:42:49] INFO     Processing target with initial shape (70000, 2)                  ]8;id=857542;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=830402;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#243\243]8;;\
#            INFO     Keeping all columns                                             ]8;id=663167;file:///home/james/dev/drnb-plugin/src/drnb/preprocess.py\preprocess.py]8;;\:]8;id=160061;file:///home/james/dev/drnb-plugin/src/drnb/preprocess.py#90\90]8;;\
#            INFO     Writing target for fashion                                       ]8;id=68156;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=772049;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#298\298]8;;\
#            INFO     Exporting data of type DataFrame to feather                      ]8;id=106133;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=594970;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#659\659]8;;\
#            INFO     Exporting data of type DataFrame to csv                          ]8;id=383766;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=519580;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#659\659]8;;\
#            INFO     Calculating nearest neighbors                                    ]8;id=63787;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=398926;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#317\317]8;;\
# [21:42:53] INFO     Using 'faiss' to find nearest neighbors                           ]8;id=805510;file:///home/james/dev/drnb-plugin/src/drnb/neighbors/compute.py\compute.py]8;;\:]8;id=579467;file:///home/james/dev/drnb-plugin/src/drnb/neighbors/compute.py#263\263]8;;\
#            INFO     Finding 151 neighbors using plugin faiss with euclidean metric    ]8;id=926087;file:///home/james/dev/drnb-plugin/src/drnb/neighbors/compute.py\compute.py]8;;\:]8;id=248528;file:///home/james/dev/drnb-plugin/src/drnb/neighbors/compute.py#123\123]8;;\
#                     and params: {'use_gpu': True}
#            INFO     [nn-plugin:faiss] launching: /home/james/.local/bin/uv run       ]8;id=625801;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py\external.py]8;;\:]8;id=279607;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py#188\188]8;;\
#                     --color never --quiet drnb-nn-plugin-run.py --method faiss
#                     --request /tmp/drnb-nn-faiss-kbtuyldi/request.json
#            INFO     [faiss] request metric=euclidean n_neighbors=151                 ]8;id=269690;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py\external.py]8;;\:]8;id=605349;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py#287\287]8;;\
#            INFO     [faiss] params={'use_gpu': True}                                 ]8;id=405540;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py\external.py]8;;\:]8;id=437730;file:///home/james/dev/drnb-plugin/src/drnb/nnplugins/external.py#287\287]8;;\
# [21:43:11] INFO     Writing numpy format to                                          ]8;id=693879;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=502224;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#432\432]8;;\
#                     nn/fashion.16.euclidean.exact.faiss.idx.npy
# [21:43:13] INFO     Writing csv format to                                            ]8;id=45813;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=206087;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#404\404]8;;\
#                     nn/fashion.16.euclidean.exact.faiss.idx.csv
# [21:43:14] INFO     Writing numpy format to                                          ]8;id=49339;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=305927;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#432\432]8;;\
#                     nn/fashion.16.euclidean.exact.faiss.dist.npy
# [21:43:16] INFO     Writing csv format to                                            ]8;id=605521;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=449648;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#404\404]8;;\
#                     nn/fashion.16.euclidean.exact.faiss.dist.csv
# [21:43:18] INFO     Writing numpy format to                                          ]8;id=257483;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=964585;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#432\432]8;;\
#                     nn/fashion.51.euclidean.exact.faiss.idx.npy
# [21:43:23] INFO     Writing csv format to                                            ]8;id=86285;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=34744;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#404\404]8;;\
#                     nn/fashion.51.euclidean.exact.faiss.idx.csv
# [21:43:28] INFO     Writing numpy format to                                          ]8;id=218587;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=800997;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#432\432]8;;\
#                     nn/fashion.51.euclidean.exact.faiss.dist.npy
# [21:43:33] INFO     Writing csv format to                                            ]8;id=267499;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=475646;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#404\404]8;;\
#                     nn/fashion.51.euclidean.exact.faiss.dist.csv
# [21:43:39] INFO     Writing numpy format to                                          ]8;id=375310;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=477594;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#432\432]8;;\
#                     nn/fashion.151.euclidean.exact.faiss.idx.npy
#            INFO     Writing csv format to                                            ]8;id=127637;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=653742;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#404\404]8;;\
#                     nn/fashion.151.euclidean.exact.faiss.idx.csv
# [21:43:50] INFO     Writing numpy format to                                          ]8;id=778903;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=651456;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#432\432]8;;\
#                     nn/fashion.151.euclidean.exact.faiss.dist.npy
#            INFO     Writing csv format to                                            ]8;id=253384;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=772149;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#404\404]8;;\
#                     nn/fashion.151.euclidean.exact.faiss.dist.csv
# [21:44:04] INFO     Calculating triplets                                             ]8;id=445822;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=278704;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#331\331]8;;\
# [21:44:05] INFO     Writing csv format to triplets/fashion.5.1337.idx.csv            ]8;id=600159;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=698936;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#404\404]8;;\
# [21:44:07] INFO     Writing csv format to triplets/fashion.5.1337.euclidean.csv      ]8;id=562690;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=956643;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#404\404]8;;\
# [21:44:09] INFO     Writing numpy format to triplets/fashion.5.1337.idx.npy          ]8;id=711362;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=375860;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#432\432]8;;\
#            INFO     Writing numpy format to triplets/fashion.5.1337.euclidean.npy    ]8;id=751488;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py\__init__.py]8;;\:]8;id=9884;file:///home/james/dev/drnb-plugin/src/drnb/io/__init__.py#432\432]8;;\
#            INFO     Writing pipeline result for fashion                              ]8;id=639245;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=646165;file:///home/james/dev/drnb-plugin/src/drnb/io/pipeline.py#134\134]8;;\
