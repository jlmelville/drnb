# %%
# %load_ext lab_black
# %load_ext autotime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# time: 630 ms (started: 2023-03-09 21:06:16 -08:00)

# %% [markdown]
# A 2D dataset consisting of 2 clusters inserted into some noise, from a [google colab notebook by Pavlin Poličar](https://colab.research.google.com/drive/1-8vLka6Cwj8rE4G48w0C7kXqQJLkZrQH?usp=sharing) (originally found in a [tweet](https://twitter.com/pavlinpolicar/status/1633901494784147464)), designed to demonstrate some problems with UMAP and t-SNE distinguishing noise from clusters.

# %%
x1 = np.random.uniform(-5, 5, size=(1000, 2))
x2 = np.random.normal((0, 2.5), 0.1, size=(250, 2))
x3 = np.random.normal((0, -2.5), 0.1, size=(250, 2))
x = np.vstack([x1, x2, x3])
y = np.hstack([0 * np.ones(1000), 1 * np.ones(250), 2 * np.ones(250)]).astype(int)

c = np.array(["#666666", "#1f77b4", "#d62728"])[y]

plt.scatter(x[:, 0], x[:, 1], alpha=0.25, s=12, c=c)
# Out:
# time: 183 ms (started: 2023-03-09 21:06:16 -08:00)

# %%
from drnb.io.pipeline import create_default_pipeline

data_pipe = create_default_pipeline(
    check_for_duplicates=False,
)
# Out:
# [21:06:21] INFO     Requesting one extra neighbor to account for self-neighbor                      ]8;id=9552;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py\__init__.py]8;;\:]8;id=700060;file:///home/james/dev/drnb/src/drnb/neighbors/__init__.py#560\560]8;;\
# time: 4.16 s (started: 2023-03-09 21:06:16 -08:00)

# %%
data_result = data_pipe.run(
    "embdensity",
    data=x,
    target=pd.DataFrame({"cluster": c}),
    url="https://colab.research.google.com/drive/1-8vLka6Cwj8rE4G48w0C7kXqQJLkZrQH",
    tags=["small", "lowdim"],
    verbose=True,
)
# Out:
#            INFO     Initial data shape: (1500, 2)                                                    ]8;id=797007;file:///home/james/dev/drnb/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=83650;file:///home/james/dev/drnb/src/drnb/io/pipeline.py#75\75]8;;\
#            INFO     Keeping all columns                                                            ]8;id=591463;file:///home/james/dev/drnb/src/drnb/preprocess.py\preprocess.py]8;;\:]8;id=959618;file:///home/james/dev/drnb/src/drnb/preprocess.py#67\67]8;;\
#            INFO     Data shape after filtering columns: (1500, 2)                                   ]8;id=801754;file:///home/james/dev/drnb/src/drnb/io/pipeline.py\pipeline.py]8;;\:]8;id=345107;file:///home/james/dev/drnb/src/drnb/io/pipeline.py#146\146]8;;\
# ...

# %% [markdown]
# In a [subsequent tweet](https://twitter.com/pavlinpolicar/status/1633901499049754639) Pavlin notes that DensMAP should be better than UMAP for avoiding giving the appearance of clustering the noise.

# %%
import drnb.embed.pipeline as pl
# Out:
# time: 3.08 s (started: 2023-03-09 21:06:25 -08:00)

# %%
pl.standard_eval(
    method="umap",
    dataset="embdensity",
)
# Out:
# [EvalResult(eval_type='RTE', label='rte-5-euclidean', value=0.7705333333333333, info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='RPC', label='rpc-5-euclidean', value=0.6259673195778678, info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='NNP', label='nnp-15-noself-euclidean', value=0.7670666666666666, info={'metric': 'euclidean', 'n_neighbors': 15}),
#  EvalResult(eval_type='NNP', label='nnp-50-noself-euclidean', value=0.7709066666666667, info={'metric': 'euclidean', 'n_neighbors': 50}),
#  EvalResult(eval_type='NNP', label='nnp-150-noself-euclidean', value=0.7759244444444445, info={'metric': 'euclidean', 'n_neighbors': 150})]
# time: 6.37 s (started: 2023-03-09 21:06:28 -08:00)

# %%
pl.standard_eval(
    method="umap",
    params=dict(densmap=True),
    dataset="embdensity",
)
# Out:
# [EvalResult(eval_type='RTE', label='rte-5-euclidean', value=0.8113333333333334, info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='RPC', label='rpc-5-euclidean', value=0.7728213877947533, info={'metric': 'euclidean', 'ntpp': 5}),
#  EvalResult(eval_type='NNP', label='nnp-15-noself-euclidean', value=0.7134222222222223, info={'metric': 'euclidean', 'n_neighbors': 15}),
#  EvalResult(eval_type='NNP', label='nnp-50-noself-euclidean', value=0.7586666666666667, info={'metric': 'euclidean', 'n_neighbors': 50}),
#  EvalResult(eval_type='NNP', label='nnp-150-noself-euclidean', value=0.8044755555555556, info={'metric': 'euclidean', 'n_neighbors': 150})]
# time: 7.59 s (started: 2023-03-09 21:06:35 -08:00)

# %% [markdown]
# That seems like a reasonable conclusion.
