# %%
# %load_ext lab_black
# %load_ext autotime
import pandas as pd
import numpy as np
import drnb as nb
# Out:
# time: 245 ms (started: 2022-09-16 23:26:38 -07:00)

# %%
from drnb.io.dataset import get_available_data_info, list_available_data
# Out:
# time: 379 ms (started: 2022-09-16 23:26:38 -07:00)

# %% [markdown]
# `get_available_data_info` provides an overview of datasets which have gone through the data pipeline. Some columns of note:
#
# * `n_items`: number of rows.
# * `n_dim`: number of columns.
# * `n_target_cols`: number of columns in the `target` metadata.
# * `n_na_rows`: how many rows of the original data were removed for containing missing entries.
# * `scale`: if any scaling was carried out, e.g. `z` means Z-scaling/standard scaling.
# * `dim_red`: was any initial dimensionality reduction carried out, for example PCA. In that case, the amount of variance explained is also recorded.
# * `n_duplicates`: how many rows are duplicated in the dataset (this occurs after remove `na` rows and column selection).

# %% [markdown]
# If all the notebooks in this folder are run, you should get something out like the following:

# %%
get_available_data_info()
# Out:
#                     n_items  n_dim n_target_cols  n_na_rows scale  \
# name
# avonet                11009     11             3          0     z
# cifar10               60000   3072             2          0  None
# cifar10act            60000    512             2          0  None
# coil100                7200  49152             3          0  None
# coil20                 1440  16384             2          0  None
# fashion               70000    784             1          0  None
# frey                   1965    560          None          0  None
# iris                    150      4             2          0  None
# isofaces                698   4096             2          0  None
# isoswiss              20000      3             2          0  None
# kuzushiji             70000    784             1          0  None
# lamanno2020            3850   1999             3          0  None
# macosko2015           44808   3000             2          0  None
# macosko2015z          44808   3000             2          0     z
# macosko2015z-pca50    44808     50             2          0     z
# mammoth               50000      3          None          0  None
# mnist                 70000    784             1          0  None
# ng20                  18846   3000             2          0  None
# norb                  48600   9216             6          0  None
# olivetti                400   4096             2          0  None
# olivetti92x112          400  10304             2          0  None
# penguins                342      4             3          2     z
# s1k                    1000      9             1          0  None
# scurvehole             9505      3             1          0  None
# tasic2018             23822   3000             3          0  None
# tasic2018-pca50       23822     50             3          0  None
#
#                             dim_red n_duplicates  \
# name
# avonet                         None          297
# cifar10                        None            0
# cifar10act                     None            0
# coil100                        None            0
# coil20                         None            0
# fashion                        None            0
# frey                           None            0
# iris                           None            1
# isofaces                       None            0
# isoswiss                       None            0
# kuzushiji                      None            0
# lamanno2020                    None            0
# macosko2015                    None            0
# macosko2015z                   None         None
# macosko2015z-pca50  PCA 50 (23.48%)         None
# mammoth                        None            0
# mnist                          None            0
# ng20                           None            5
# norb                           None            0
# olivetti                       None            0
# olivetti92x112                 None            0
# penguins                       None            0
# s1k                            None            0
# scurvehole                     None            0
# tasic2018                      None            0
# tasic2018-pca50     PCA 50 (62.64%)         None
#
#                                             tags           created_on  \
# name
# avonet                              small lowdim  2022-09-16 05:34:19
# cifar10                                    image  2022-09-16 07:04:33
# cifar10act                           activations  2022-09-17 06:13:50
# coil100                           image vhighdim  2022-09-16 06:50:24
# lamanno2020         https://github.com/pachterlab/picasso/blob/mai...
# macosko2015                https://doi.org/10.1016/j.cell.2015.05.002
# macosko2015z               https://doi.org/10.1016/j.cell.2015.05.002
# macosko2015z-pca50         https://doi.org/10.1016/j.cell.2015.05.002
# mammoth               https://github.com/PAIR-code/understanding-umap
# mnist                               http://yann.lecun.com/exdb/mnist/
# ng20                            http://qwone.com/~jason/20Newsgroups/
# norb                 https://cs.nyu.edu/~ylclab/data/norb-v1.0-small/
# olivetti                      https://cam-orl.co.uk/facedatabase.html
# olivetti92x112                                                   None
# penguins               https://allisonhorst.github.io/palmerpenguins/
# s1k                                                              None
# scurvehole                      https://github.com/YingfanWang/PaCMAP
# tasic2018                   https://doi.org/10.1038/s41586-018-0654-5
# tasic2018-pca50             https://doi.org/10.1038/s41586-018-0654-5
# time: 204 ms (started: 2022-09-16 23:35:12 -07:00)

# %% [markdown]
# The idea around the tags:
# * `small`: a small dataset, < 4096 items. This is the cutoff point where UMAP will go from exact nearest neighbors to approximate, although how onerous it is to get exact nearest neighbors is also a function of the dimensionality of the data too, hence the following classifications:
# * `lowdim`: a dataset with < 100 features.
# * `highdim`: a dataset with 1000-9999 features. Many nearest neighbor routines start having trouble here.
# * `vhighdim`: a dataset with >= 10000 features. The temptation to run PCA on such large datasets is almost overwhelming. Nearest neighbor methods tend to be quite slow with these methods and also the results may not be what you want (there tends to be hubs formed).
#     * I don't have a tag for 100-999 features. That's pretty "normal" in terms of suitability for dimensionality reduction vs challenge.
# * `image`: the dataset consists of images.
# * `scRNAseq`: single cell RNA sequence data.
# * `synthetic`: artificial data to test some aspect of a dimensionality reduction or manifold learning method. Or real data used to a similar end (e.g. `mammoth`).

# %% [markdown]
# A simpler, but related function:

# %%
list_available_data()
# Out:
# ['avonet',
#  'cifar10',
#  'coil100',
#  'coil20',
#  'fashion',
#  'frey',
#  'iris',
#  'isofaces',
#  'isoswiss',
#  'kuzushiji',
#  'lamanno2020',
#  'macosko2015',
#  'macosko2015z',
#  'macosko2015z-pca50',
#  'mammoth',
#  'mnist',
#  'ng20',
#  'norb',
#  'olivetti',
#  'olivetti92x112',
#  'penguins',
#  's1k',
#  'scurvehole',
#  'tasic2018',
#  'tasic2018-pca50']
# time: 9.09 ms (started: 2022-09-16 07:48:16 -07:00)

# %%
list_available_data(with_target=True)
# Out:
# ['avonet',
#  'cifar10',
#  'coil100',
#  'coil20',
#  'fashion',
#  'iris',
#  'isofaces',
#  'isoswiss',
#  'kuzushiji',
#  'lamanno2020',
#  'macosko2015',
#  'macosko2015z',
#  'macosko2015z-pca50',
#  'mnist',
#  'ng20',
#  'norb',
#  'olivetti',
#  'olivetti92x112',
#  'penguins',
#  's1k',
#  'scurvehole',
#  'tasic2018',
#  'tasic2018-pca50']
# time: 16.6 ms (started: 2022-09-16 07:48:16 -07:00)
