# %%
# %load_ext lab_black
# %load_ext autotime
import numpy as np
import pandas as pd

import drnb as nb
# Out:
# time: 591 ms (started: 2023-07-22 11:41:15 -07:00)

# %%
from drnb.io.dataset import get_available_dataset_info, list_available_datasets
# Out:
# time: 666 ms (started: 2023-07-22 11:41:16 -07:00)

# %% [markdown]
# `get_available_dataset_info` provides an overview of datasets which have gone through the data pipeline. Some columns of note:
#
# * `n_items`: number of rows.
# * `n_dim`: number of columns.
# * `n_target_cols`: number of columns in the `target` metadata.
# * `n_na_rows`: how many rows of the original data were removed for containing missing entries.
# * `scale`: if any scaling was carried out, e.g. `z` means Z-scaling/standard scaling.
# * `dim_red`: was any initial dimensionality reduction carried out, for example PCA. In that case, the amount of variance explained is also recorded.
# * `n_duplicates`: how many rows are duplicated in the dataset (this occurs after remove `na` rows and column selection).

# %% [markdown]
# If all the notebooks in this folder are run, you should get something out like the following:

# %%
df = get_available_dataset_info()
# Out:
# [11:42:03] WARNING  Bad datasets found: ['galaxy10decals']                                           ]8;id=151539;file:///home/james/dev/drnb/src/drnb/io/dataset.py\dataset.py]8;;\:]8;id=555341;file:///home/james/dev/drnb/src/drnb/io/dataset.py#157\157]8;;\
# time: 2.74 s (started: 2023-07-22 11:42:00 -07:00)

# %%
df.loc[
    [
        "isoswiss",
        "scurvehole",
        "mammoth",
        "s1k",
        "spheres",
        "mnist",
        "tasic2018-pca50",
        "macosko2015-pca50",
    ],
    :,
]
# Out:
#                   n_items n_dim n_target_cols n_na_rows scale  \
# name
# isoswiss            20000     3             2         0  None
# scurvehole           9505     3             1         0  None
# mammoth             50000     3          None         0  None
# s1k                  1000     9             1         0  None
# spheres             10000   101             1         0  None
# mnist               70000   784             1         0  None
# tasic2018-pca50     23822    50             3         0  None
# macosko2015-pca50   44808    50             2         0  None
#
#                            dim_red n_duplicates                     tags  \
# name
# isoswiss                      None            0  synthetic lowdim isomap
# scurvehole                    None            0         lowdim synthetic
# mammoth                       None            0         lowdim synthetic
# s1k                           None            0             small lowdim
# spheres                       None         None                synthetic
# mnist                         None            0                    image
# tasic2018-pca50    PCA 50 (62.64%)         None                 scRNAseq
# macosko2015-pca50  PCA 50 (30.02%)         None                 scRNAseq
#
#                             created_on           updated_on  \
# name
# isoswiss           2022-09-16 06:01:34  2022-09-16 06:01:34
# scurvehole         2022-09-16 06:01:58  2022-09-16 06:01:58
# mammoth            2022-09-16 06:13:48  2022-09-16 06:13:48
# s1k                2022-12-28 00:32:16  2022-12-28 00:32:16
# spheres            2023-04-06 05:48:04  2023-04-06 05:48:04
# mnist              2023-05-03 04:53:27  2023-05-03 04:53:27
# tasic2018-pca50    2022-09-18 00:36:27  2022-09-18 00:36:27
# macosko2015-pca50  2023-06-11 02:53:31  2023-06-11 02:53:31
#
#                                                                  url
# name
# isoswiss                                                        None
# scurvehole                     https://github.com/YingfanWang/PaCMAP
# mammoth              https://github.com/PAIR-code/understanding-umap
# s1k                                                             None
# spheres            https://github.com/BorgwardtLab/topological-au...
# mnist                              http://yann.lecun.com/exdb/mnist/
# tasic2018-pca50            https://doi.org/10.1038/s41586-018-0654-5
# macosko2015-pca50         https://doi.org/10.1016/j.cell.2015.05.002
# time: 21.1 ms (started: 2023-07-22 11:43:14 -07:00)

# %%
get_available_dataset_info()
# Out:
# [11:41:20] WARNING  Bad datasets found: ['galaxy10decals']                                           ]8;id=446526;file:///home/james/dev/drnb/src/drnb/io/dataset.py\dataset.py]8;;\:]8;id=263201;file:///home/james/dev/drnb/src/drnb/io/dataset.py#157\157]8;;\
#                     n_items n_dim n_target_cols n_na_rows scale  \
# name
# 1kgp                   3450   868             3         0  None
# 1kgp-pca50             3450    50             3         0  None
# airfoil                1503     5             1         0     z
# avonet                11009    11             3         0     z
# cifar10               60000  3072             2         0  None
# ...                     ...   ...           ...       ...   ...
# tomoradar-z-pca1000  120024  1000             1         0     z
# two_gaussians100d     10000   100             1         0  None
# two_gaussians2d       10000     2             1         0  None
# two_gaussians5d       10000     5             1         0  None
# vocation-map           1227    10             1         0  None
#
#                                dim_red n_duplicates          tags  \
# name
# 1kgp                              None            0
# 1kgp-pca50             PCA 50 (27.53%)         None
# airfoil                           None            0        lowdim
# avonet                            None          297  small lowdim
# cifar10                           None            0         image
# ...                                ...          ...           ...
# tomoradar-z-pca1000  PCA 1000 (77.21%)         None
# two_gaussians100d                 None         None     synthetic
# two_gaussians2d                   None         None     synthetic
# two_gaussians5d                   None         None     synthetic
# vocation-map                      None            0  small lowdim
#
#                               created_on           updated_on  \
# name
# 1kgp                 2022-12-18 07:39:55  2022-12-18 07:39:55
# 1kgp-pca50           2022-12-18 07:40:06  2022-12-18 07:40:06
# airfoil              2022-12-25 21:56:05  2022-12-25 21:56:05
# avonet               2022-09-16 05:34:19  2022-09-16 05:34:19
# cifar10              2022-09-19 05:46:39  2022-09-19 05:46:39
# ...                                  ...                  ...
# tomoradar-z-pca1000  2022-09-20 18:13:23  2022-09-20 18:13:23
# two_gaussians100d    2023-02-13 01:09:29  2023-02-13 01:09:29
# two_gaussians2d      2023-02-13 01:07:22  2023-02-13 01:07:22
# two_gaussians5d      2023-02-13 01:08:25  2023-02-13 01:08:25
# vocation-map         2023-06-27 05:02:34  2023-06-27 05:02:34
#
#                                                                    url
# name
# 1kgp                      https://doi.org/10.1371/journal.pgen.1008432
# 1kgp-pca50                https://doi.org/10.1371/journal.pgen.1008432
# airfoil              https://archive.ics.uci.edu/ml/datasets/airfoi...
# avonet                               https://doi.org/10.1111/ele.13898
# cifar10                    https://www.cs.toronto.edu/~kriz/cifar.html
# ...                                                                ...
# tomoradar-z-pca1000                   https://github.com/rozyangno/sce
# two_gaussians100d                                                 None
# two_gaussians2d                                                   None
# two_gaussians5d                                                   None
# vocation-map                   https://doi.org/10.1073/pnas.1917942116
#
# [117 rows x 11 columns]
# time: 3.54 s (started: 2023-07-22 11:41:16 -07:00)

# %% [markdown]
# The idea around the tags:
# * `small`: a small dataset, < 4096 items. This is the cutoff point where UMAP will go from exact nearest neighbors to approximate, although how onerous it is to get exact nearest neighbors is also a function of the dimensionality of the data too, hence the following classifications:
# * `lowdim`: a dataset with < 100 features.
# * `highdim`: a dataset with 1000-9999 features. Many nearest neighbor routines start having trouble here.
# * `vhighdim`: a dataset with >= 10000 features. The temptation to run PCA on such large datasets is almost overwhelming. Nearest neighbor methods tend to be quite slow with these methods and also the results may not be what you want (there tends to be hubs formed).
#     * I don't have a tag for 100-999 features. That's pretty "normal" in terms of suitability for dimensionality reduction vs challenge.
# * `image`: the dataset consists of images.
# * `scRNAseq`: single cell RNA sequence data.
# * `synthetic`: artificial data to test some aspect of a dimensionality reduction or manifold learning method. Or real data used to a similar end (e.g. `mammoth`).

# %% [markdown]
# A simpler, but related function:

# %%
list_available_datasets()
# Out:
# ['avonet',
#  'cifar10',
#  'cifar10act',
#  'coil100',
#  'coil20',
#  'fashion',
#  'frey',
#  'iris',
#  'isofaces',
#  'isoswiss',
#  'kuzushiji',
#  'lamanno2020',
#  'macosko2015',
#  'macosko2015-pca50',
#  'macosko2015z',
#  'macosko2015z-pca50',
#  'mammoth',
#  'mnist',
#  'ng20',
#  'norb',
#  'olivetti',
#  'olivetti92x112',
#  'penguins',
#  's1k',
#  'scurvehole',
#  'tasic2018',
#  'tasic2018-pca50']
# time: 8.79 ms (started: 2022-09-18 16:37:34 -07:00)

# %%
list_available_datasets(with_target=True)
# Out:
# ['avonet',
#  'cifar10',
#  'cifar10act',
#  'coil100',
#  'coil20',
#  'fashion',
#  'iris',
#  'isofaces',
#  'isoswiss',
#  'kuzushiji',
#  'lamanno2020',
#  'macosko2015',
#  'macosko2015-pca50',
#  'macosko2015z',
#  'macosko2015z-pca50',
#  'mnist',
#  'ng20',
#  'norb',
#  'olivetti',
#  'olivetti92x112',
#  'penguins',
#  's1k',
#  'scurvehole',
#  'tasic2018',
#  'tasic2018-pca50']
# time: 16.8 ms (started: 2022-09-18 16:37:34 -07:00)
